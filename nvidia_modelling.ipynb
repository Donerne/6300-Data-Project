# %%
# Importing Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import MinMaxScaler
import sklearn.model_selection as skm
from functools import reduce
from itertools import chain
import random
from scipy.stats import pearsonr, spearmanr

from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import Lasso, LassoCV
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout, BatchNormalization, Bidirectional
from tensorflow.keras.optimizers.schedules import ExponentialDecay
import tensorflow as tf
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.regularizers import l1_l2



pd.options.display.max_rows = None  # Show all rows
pd.options.display.max_columns = None  # Show all columns
pd.options.display.max_colwidth = None  # Ensure full content is visible
pd.set_option('display.float_format', '{:.9f}'.format)  # Adjust decimal places as needed

# %%
nvda_data = pd.read_csv("full_complete_datasets/NVDA_raw_complete_data.csv")

nvda_data.describe()
# Out:
# C:\Users\ekf98\AppData\Local\Temp\ipykernel_17832\1039184103.py:1: DtypeWarning: Columns (69,81,93,105,117,129,141,155) have mixed types. Specify dtype option on import or set low_memory=False.
#   nvda_data = pd.read_csv("full_complete_datasets/NVDA_raw_complete_data.csv")
#           NVDA_close      NVDA_high       NVDA_low      NVDA_open  \
# count 6640.000000000 6640.000000000 6640.000000000 6640.000000000
# mean   111.073420994  113.111471596  108.836587470  111.023289654
# std    165.192360399  167.819546917  162.099648345  165.085905954
# min      5.900000000    6.380000000    5.750000000    6.000000000
# 25%     17.545000000   17.877500000   17.195625000   17.560000000
# 50%     32.170000000   32.825000000   31.500000000   32.215000000
# 75%    149.890000000  153.335000000  146.620000000  150.635000000
# max   1224.400000000 1255.870000000 1183.200000000 1240.480000000
#
#         NVDA_traded_volume  NVDA_adjClose    NVDA_adjLow   NVDA_adjOpen  \
# count       6640.000000000 6640.000000000 6640.000000000 6640.000000000
# mean    23904924.177861445    8.963804302    8.783048523    8.968542012
# std    123422362.737983823   24.370408745   23.877238600   24.411705806
# min        41000.000000000    0.031298881    0.030572778    0.032005877
# 25%      6065705.750000000    0.258359049    0.250964291    0.257919501
# 50%     10323928.000000000    0.437516481    0.430846873    0.437370195
# 75%     18703088.000000000    4.639901180    4.577830368    4.634416918
# max   9232320000.000000000  149.430000000  147.820100000  153.030000000
#
#        NVDA_adj_traded_volume   NVDA_divCash  NVDA_splitFactor             pe  \
# count          6640.000000000 6640.000000000    6640.000000000 6395.000000000
# mean      652078764.885993958    0.000738705       1.002334337   55.425509270
# std      4544895718.629506111    0.009536156       0.118491941   95.291454552
# min        19679990.000000000    0.000000000       1.000000000    0.090776743
# 25%       337900390.000000000    0.000000000       1.000000000    9.909495250
# 50%       498777000.000000000    0.000000000       1.000000000   23.462569320
# 75%       728729635.000000000    0.000000000       1.000000000   44.363362125
# max    369292800000.000000000    0.160000000      10.000000000  413.148026500
#
#        basicMaterialsChangesPercentage  \
# count                      0.000000000
# mean                               NaN
# std                                NaN
# min                                NaN
# 25%                                NaN
# 50%                                NaN
# 75%                                NaN
# max                                NaN
#
#        communicationServicesChangesPercentage  \
# count                          5037.000000000
# mean                             -0.006930161
# std                               2.042704704
# min                             -22.740280000
# 25%                              -0.838010000
# 50%                               0.046460000
# 75%                               0.880960000
# max                              36.229460000
#
#        consumerCyclicalChangesPercentage  consumerDefensiveChangesPercentage  \
# count                     5037.000000000                      5037.000000000
# mean                        -0.093246780                         0.004878400
# std                          5.374407923                         1.500236924
# min                        -36.626610000                       -28.030260000
# 25%                         -1.680970000                        -0.512610000
# 50%                         -0.026570000                         0.046170000
# 75%                          1.236040000                         0.559450000
# max                         54.473680000                        25.934750000
#
#        energyChangesPercentage  financialServicesChangesPercentage  \
# count           5037.000000000                         0.000000000
# mean              -0.029311259                                 NaN
# std                2.328605109                                 NaN
# min              -25.725860000                                 NaN
# 25%               -1.125100000                                 NaN
# 50%                0.082300000                                 NaN
# 75%                1.171600000                                 NaN
# max               18.396900000                                 NaN
#
#        healthcareChangesPercentage  industrialsChangesPercentage  \
# count               5037.000000000                5037.000000000
# mean                  -0.073878654                  -0.209545400
# std                    4.083799934                   3.566739298
# min                  -47.464650000                 -56.171350000
# 25%                   -1.584190000                  -1.194790000
# 50%                   -0.016510000                  -0.007150000
# 75%                    1.388780000                   0.961850000
# max                   48.830410000                  47.690570000
#
#        realEstateChangesPercentage  technologyChangesPercentage  \
# count               5037.000000000               5037.000000000
# mean                   0.000519190                 -0.080692738
# std                    1.623088316                  5.307209933
# min                  -16.086320000                -74.893150000
# 25%                   -0.618800000                 -0.451220000
# 50%                    0.069800000                  0.000050000
# 75%                    0.690370000                  0.590710000
# max                   14.793820000                 58.860550000
#
#        utilitiesChangesPercentage         month1         month2  \
# count              5037.000000000 5951.000000000 1607.000000000
# mean                  0.031816625    1.570974626    2.524436839
# std                   1.403592721    1.798859020    2.157368598
# min                 -12.385570000    0.000000000    0.000000000
# 25%                  -0.591880000    0.070000000    0.110000000
# 50%                   0.075360000    0.930000000    2.290000000
# 75%                   0.703670000    2.400000000    4.800000000
# max                  17.015120000    6.020000000    5.610000000
#
#               month3         month6          year1          year2  \
# count 6589.000000000 6592.000000000 6592.000000000 6592.000000000
# mean     1.976406131    2.077111650    2.148886529    2.329742112
# std      2.028928300    2.031066210    1.956435464    1.848361138
# min      0.000000000    0.020000000    0.040000000    0.090000000
# 25%      0.110000000    0.170000000    0.277500000    0.660000000
# 50%      1.240000000    1.480000000    1.575000000    1.820000000
# 75%      3.940000000    4.160000000    4.100000000    4.070000000
# max      6.420000000    6.550000000    6.440000000    6.930000000
#
#                year3          year5          year7         year10  \
# count 6592.000000000 6592.000000000 6592.000000000 6592.000000000
# mean     2.498152306    2.842295206    3.139959041    3.378260012
# std      1.739486890    1.568122592    1.472728237    1.360843265
# min      0.100000000    0.190000000    0.360000000    0.520000000
# 25%      0.970000000    1.560000000    1.970000000    2.240000000
# 50%      2.150000000    2.670000000    3.030000000    3.440000000
# 75%      4.060000000    4.140000000    4.280000000    4.400000000
# max      6.880000000    6.830000000    6.870000000    6.790000000
#
#               year20         year30  inflationRate  Palladium_price  \
# count 6592.000000000 5587.000000000 5596.000000000   6620.000000000
# mean     3.891207524    3.758612851    2.094058256    813.654463734
# std      1.357521548    1.214704185    0.400515561    619.615621122
# min      0.870000000    0.990000000    0.040000000    148.500000000
# 25%      2.710000000    2.890000000    1.850000000    349.712500000
# 50%      4.090000000    3.660000000    2.190000000    676.450000000
# 75%      4.910000000    4.640000000    2.360000000    974.662500000
# max      6.970000000    6.750000000    3.020000000   2981.900000000
#
#        Palladium_volume  Palladium_open  Palladium_close   Copper_price  \
# count    6620.000000000  6620.000000000   6620.000000000 6622.000000000
# mean     2453.683685801   813.436820254    813.654463734    2.647232664
# std      2258.364111639   620.052037059    619.615621122    1.192197908
# min         0.000000000   148.000000000    148.500000000    0.606000000
# 25%       516.750000000   348.725000000    349.712500000    1.536250000
# 50%      1898.000000000   675.075010000    676.450000000    2.902000000
# 75%      3834.500000000   973.850000000    974.662500000    3.557250000
# max     15529.000000000  3158.000000000   2981.900000000    5.106000000
#
#          Copper_volume    Copper_open   Copper_close  Lithium_price  \
# count   6622.000000000 6622.000000000 6622.000000000 3715.000000000
# mean   39861.584566596    2.646534808    2.647232664   38.646576043
# std    33197.178125718    1.192256042    1.192197908   17.519957340
# min       10.000000000    0.606000000    0.606000000   17.250000000
# 25%     9712.250000000    1.528375000    1.536250000   25.900000000
# 50%    36138.000000000    2.903500000    2.902000000   31.820000000
# 75%    61209.750000000    3.557750000    3.557250000   44.395000000
# max   272593.000000000    5.107500000    5.106000000   96.310000000
#
#          Lithium_volume   Lithium_open  Lithium_close   Silver_price  \
# count    3715.000000000 3715.000000000 3715.000000000 6629.000000000
# mean   278314.323553163   38.659956931   38.646576043   16.382910288
# std    373263.623124241   17.526407971   17.519957340    8.773894838
# min       850.000000000   17.250000000   17.250000000    4.060000000
# 25%     16700.000000000   25.910000000   25.900000000    7.455000000
# 50%    120300.000000000   31.820000000   31.820000000   16.432000000
# 75%    418884.500000000   44.510000000   44.395000000   22.424000000
# max   5146045.000000000   96.750000000   96.310000000   48.430000000
#
#          Silver_volume    Silver_open   Silver_close     Gold_price  \
# count   6629.000000000 6629.000000000 6629.000000000 6629.000000000
# mean   54094.596470056   16.379700965   16.382910288 1115.900144553
# std    78437.705798692    8.773096277    8.773894838  614.806270813
# min        0.000000000    4.070000000    4.060000000  252.550000000
# 25%        0.000000000    7.435000000    7.455000000  442.950000000
# 50%    28495.000000000   16.432000000   16.432000000 1213.260000000
# 75%    74755.000000000   22.418000000   22.424000000 1587.800000000
# max   769212.000000000   48.430000000   48.430000000 2952.900000000
#
#             Gold_volume      Gold_open     Gold_close    CADUSD_open  \
# count    6629.000000000 6629.000000000 6629.000000000 1269.000000000
# mean   154612.728918389 1115.541948743 1115.900144553    0.754489606
# std    202685.760277486  614.534597594  614.806270813    0.031339410
# min         0.000000000  252.350000000  252.550000000    0.687900000
# 25%         0.000000000  442.500000000  442.950000000    0.732600000
# 50%     61728.000000000 1212.840000000 1213.260000000    0.746600000
# 75%    269466.000000000 1588.200000000 1587.800000000    0.782600000
# max   2234154.000000000 2952.900000000 2952.900000000    0.830300000
#
#          CADUSD_high     CADUSD_low   CADUSD_close  CADUSD_adjClose  \
# count 1269.000000000 1269.000000000 1269.000000000   1269.000000000
# mean     0.757127218    0.752314050    0.754427849      0.754427849
# std      0.031402902    0.031363212    0.031381467      0.031381467
# min      0.693190000    0.676170000    0.688040000      0.688040000
# 25%      0.734790000    0.730550000    0.732630000      0.732630000
# 50%      0.748790000    0.744310000    0.746600000      0.746600000
# 75%      0.786000000    0.779800000    0.782680000      0.782680000
# max      0.832560000    0.828190000    0.830610000      0.830610000
#
#        CADUSD_traded_volume  CADUSD_unadjusted_traded_Volume  CADUSD_change  \
# count        1269.000000000                   1269.000000000 1269.000000000
# mean         4082.769109535                   4082.769109535   -0.000061757
# std         13924.515933154                  13924.515933154    0.003335293
# min             0.000000000                      0.000000000   -0.014840000
# 25%             0.000000000                      0.000000000   -0.002000000
# 50%             0.000000000                      0.000000000   -0.000100000
# 75%             0.000000000                      0.000000000    0.001960000
# max         84619.000000000                  84619.000000000    0.014220000
#
#        CADUSD_changePercent    CADUSD_vwap  CADUSD_changeOverTime  \
# count        1269.000000000 1269.000000000         1269.000000000
# mean           -0.007452709    0.754590717           -0.000074527
# std             0.443595977    0.031335261            0.004435960
# min            -2.108640000    0.687850000           -0.021086400
# 25%            -0.270310000    0.732890000           -0.002703100
# 50%            -0.012825450    0.746510000           -0.000128254
# 75%             0.256720000    0.783010000            0.002567200
# max             1.955500000    0.829410000            0.019555000
#
#          CHFUSD_open    CHFUSD_high     CHFUSD_low   CHFUSD_close  \
# count 1270.000000000 1270.000000000 1270.000000000 1270.000000000
# mean     1.093547843    1.097962205    1.090268559    1.093559858
# std      0.040139233    0.039924192    0.040371663    0.040170641
# min      0.986500000    0.999030000    0.985580000    0.986450000
# 25%      1.073520000    1.078397500    1.070000000    1.073785000
# 50%      1.094705000    1.098425000    1.091600000    1.094535000
# 75%      1.118292500    1.122590000    1.114955000    1.118200000
# max      1.189400000    1.199780000    1.183380000    1.189400000
#
#        CHFUSD_adjClose  CHFUSD_traded_volume  CHFUSD_unadjusted_traded_Volume  \
# count   1270.000000000        1270.000000000                   1270.000000000
# mean       1.093559858       18905.552755906                  18905.552755906
# std        0.040170641       64322.446057067                  64322.446057067
# min        0.986450000           0.000000000                      0.000000000
# 25%        1.073785000           0.000000000                      0.000000000
# 50%        1.094535000           0.000000000                      0.000000000
# 75%        1.118200000           0.000000000                      0.000000000
# max        1.189400000      311600.000000000                 311600.000000000
#
#        CHFUSD_change  CHFUSD_changePercent    CHFUSD_vwap  \
# count 1270.000000000        1270.000000000 1270.000000000
# mean     0.000012016           0.002195982    1.093835362
# std      0.005302168           0.489680328    0.040082466
# min     -0.022620000          -2.071640000    0.991920000
# 25%     -0.003170000          -0.293095000    1.073907500
# 50%     -0.000235000          -0.020888505    1.094760000
# 75%      0.003300000           0.296712500    1.118697500
# max      0.030310000           3.017450000    1.188060000
#
#        CHFUSD_changeOverTime    CNHUSD_open    CNHUSD_high     CNHUSD_low  \
# count         1270.000000000 1270.000000000 1270.000000000 1270.000000000
# mean             0.000021960    0.145102480    0.145412717    0.144934268
# std              0.004896803    0.007167875    0.007154387    0.007176833
# min             -0.020716400    0.135370000    0.135700000    0.135370000
# 25%             -0.002930950    0.138635000    0.138922500    0.138450000
# 50%             -0.000208885    0.143085000    0.143440000    0.142870000
# 75%              0.002967125    0.153027500    0.153342500    0.152827500
# max              0.030174500    0.158020000    0.158150000    0.157990000
#
#         CNHUSD_close  CNHUSD_adjClose  CNHUSD_traded_volume  \
# count 1270.000000000   1270.000000000        1270.000000000
# mean     0.145095992      0.145095992       19292.224409449
# std      0.007171760      0.007171760       64647.421735583
# min      0.135370000      0.135370000           0.000000000
# 25%      0.138620000      0.138620000           0.000000000
# 50%      0.143075000      0.143075000           0.000000000
# 75%      0.153045000      0.153045000           0.000000000
# max      0.158080000      0.158080000      334048.000000000
#
#        CNHUSD_unadjusted_traded_Volume  CNHUSD_change  CNHUSD_changePercent  \
# count                   1270.000000000 1270.000000000        1270.000000000
# mean                   19292.224409449   -0.000006488          -0.004095911
# std                    64647.421735583    0.000461208           0.321095448
# min                        0.000000000   -0.002010000          -1.431420000
# 25%                        0.000000000   -0.000240000          -0.167420000
# 50%                        0.000000000   -0.000010000          -0.006867760
# 75%                        0.000000000    0.000220000           0.152537500
# max                   334048.000000000    0.002870000           2.109050000
#
#          CNHUSD_vwap  CNHUSD_changeOverTime    KRWUSD_open    KRWUSD_high  \
# count 1270.000000000         1270.000000000 1270.000000000 1270.000000000
# mean     0.145136890           -0.000040959    0.000790882    0.000794106
# std      0.007164663            0.003210954    0.000062121    0.000061973
# min      0.135530000           -0.014314200    0.000674000    0.000677000
# 25%      0.138672500           -0.001674200    0.000743250    0.000747000
# 50%      0.143140000           -0.000068678    0.000776000    0.000780000
# 75%      0.153075000            0.001525375    0.000839000    0.000841750
# max      0.158030000            0.021090500    0.000920000    0.000922000
#
#           KRWUSD_low   KRWUSD_close  KRWUSD_adjClose  KRWUSD_traded_volume  \
# count 1270.000000000 1270.000000000   1270.000000000        1270.000000000
# mean     0.000789124    0.000790741      0.000790741        6411.032283465
# std      0.000062200    0.000062202      0.000062202       20690.277564907
# min      0.000673000    0.000673000      0.000673000           0.000000000
# 25%      0.000742000    0.000743000      0.000743000           0.000000000
# 50%      0.000772000    0.000775000      0.000775000           0.000000000
# 75%      0.000838000    0.000839000      0.000839000           0.000000000
# max      0.000918000    0.000920000      0.000920000      121280.000000000
#
#        KRWUSD_unadjusted_traded_Volume  KRWUSD_change  KRWUSD_changePercent  \
# count                   1270.000000000 1270.000000000        1270.000000000
# mean                    6411.032283465   -0.000000141          -0.017221567
# std                    20690.277564907    0.000004304           0.551819194
# min                        0.000000000   -0.000017000          -2.063110000
# 25%                        0.000000000   -0.000003000          -0.379870000
# 50%                        0.000000000    0.000000000           0.000000000
# 75%                        0.000000000    0.000003000           0.331585000
# max                   121280.000000000    0.000024000           3.069050000
#
#          KRWUSD_vwap  KRWUSD_changeOverTime    EURUSD_open    EURUSD_high  \
# count 1270.000000000         1270.000000000 1270.000000000 1270.000000000
# mean     0.000791213           -0.000172216    1.106221465    1.110363063
# std      0.000062096            0.005518192    0.059461622    0.058962165
# min      0.000674750           -0.020631100    0.959280000    0.967080000
# 25%      0.000744000           -0.003798700    1.069252500    1.073155000
# 50%      0.000775625            0.000000000    1.091825000    1.095360000
# 75%      0.000839500            0.003315850    1.159277500    1.161637500
# max      0.000919250            0.030690500    1.232370000    1.234950000
#
#           EURUSD_low   EURUSD_close  EURUSD_adjClose  EURUSD_traded_volume  \
# count 1270.000000000 1270.000000000   1270.000000000        1270.000000000
# mean     1.102366567    1.106214701      1.106214701      273804.377165354
# std      0.059909143    0.059464656      0.059464656      138721.483495254
# min      0.953580000    0.959280000      0.959280000       80925.000000000
# 25%      1.065427500    1.069290000      1.069290000      187436.000000000
# 50%      1.088355000    1.091490000      1.091490000      239989.500000000
# 75%      1.156280000    1.159437500      1.159437500      323126.750000000
# max      1.226550000    1.232370000      1.232370000     1470342.000000000
#
#        EURUSD_unadjusted_traded_Volume  EURUSD_change  EURUSD_changePercent  \
# count                   1270.000000000 1270.000000000        1270.000000000
# mean                  273804.377165354   -0.000006764           0.000518452
# std                   138721.483495254    0.005169308           0.475899456
# min                    80925.000000000   -0.021810000          -1.999250000
# 25%                   187436.000000000   -0.003147500          -0.284720000
# 50%                   239989.500000000   -0.000075000          -0.006570985
# 75%                   323126.750000000    0.003127500           0.286925000
# max                  1470342.000000000    0.021210000           2.176340000
#
#          EURUSD_vwap  EURUSD_changeOverTime    GBPUSD_open    GBPUSD_high  \
# count 1270.000000000         1270.000000000 1270.000000000 1270.000000000
# mean     1.106292079            0.000005185    1.281570535    1.287149118
# std      0.059404728            0.004758995    0.065791716    0.064878615
# min      0.961030000           -0.019992500    1.068580000    1.083720000
# 25%      1.069482500           -0.002847200    1.240367500    1.245570000
# 50%      1.092090000           -0.000065710    1.270970000    1.275335000
# 75%      1.159150000            0.002869250    1.331095000    1.336195000
# max      1.230780000            0.021763400    1.420530000    1.425040000
#
#           GBPUSD_low   GBPUSD_close  GBPUSD_adjClose  GBPUSD_traded_volume  \
# count 1270.000000000 1270.000000000   1270.000000000        1270.000000000
# mean     1.276250402    1.281604709      1.281604709      339669.683464567
# std      0.066820627    0.065788855      0.065788855      155750.159037562
# min      1.035650000    1.068580000      1.068580000       75071.000000000
# 25%      1.234255000    1.240600000      1.240600000      239000.250000000
# 50%      1.267115000    1.270970000      1.270970000      302585.000000000
# 75%      1.324207500    1.330347500      1.330347500      388197.500000000
# max      1.414560000    1.419900000      1.419900000     1146998.000000000
#
#        GBPUSD_unadjusted_traded_Volume  GBPUSD_change  GBPUSD_changePercent  \
# count                   1270.000000000 1270.000000000        1270.000000000
# mean                  339669.683464567    0.000034173           0.004371158
# std                   155750.159037562    0.007232103           0.581368985
# min                    75071.000000000   -0.043550000          -3.613630000
# 25%                   239000.250000000   -0.003997500          -0.313342500
# 50%                   302585.000000000    0.000270000           0.020900690
# 75%                   388197.500000000    0.004467500           0.346135000
# max                  1146998.000000000    0.035950000           3.165950000
#
#          GBPUSD_vwap  GBPUSD_changeOverTime    JPYUSD_open    JPYUSD_high  \
# count 1270.000000000         1270.000000000 1270.000000000 1270.000000000
# mean     1.281644409            0.000043712    0.007889144    0.007923395
# std      0.065737127            0.005813690    0.001156146    0.001153202
# min      1.069150000           -0.036136300    0.006186000    0.006199000
# 25%      1.239952500           -0.003133425    0.006794250    0.006834250
# 50%      1.271115000            0.000209007    0.007504500    0.007562500
# 75%      1.330170000            0.003461350    0.009121250    0.009146000
# max      1.418670000            0.031659500    0.009777000    0.009874000
#
#           JPYUSD_low   JPYUSD_close  JPYUSD_adjClose  JPYUSD_traded_volume  \
# count 1270.000000000 1270.000000000   1270.000000000        1270.000000000
# mean     0.007861012    0.007887007      0.007887007         297.572440945
# std      0.001156068    0.001155685      0.001155685        1004.677315432
# min      0.006176000    0.006181000      0.006181000           0.000000000
# 25%      0.006765500    0.006792500      0.006792500           0.000000000
# 50%      0.007471000    0.007504500      0.007504500           0.000000000
# 75%      0.009101750    0.009116000      0.009116000           0.000000000
# max      0.009692000    0.009774000      0.009774000        3985.000000000
#
#        JPYUSD_unadjusted_traded_Volume  JPYUSD_change  JPYUSD_changePercent  \
# count                   1270.000000000 1270.000000000        1270.000000000
# mean                     297.572440945   -0.000002137          -0.024732980
# std                     1004.677315432    0.000046612           0.608246106
# min                        0.000000000   -0.000284000          -2.976940000
# 25%                        0.000000000   -0.000026000          -0.334012500
# 50%                        0.000000000   -0.000004000          -0.045145940
# 75%                        0.000000000    0.000022000           0.278265000
# max                     3985.000000000    0.000286000           3.915130000
#
#          JPYUSD_vwap  JPYUSD_changeOverTime            sma            adx  \
# count 1270.000000000         1270.000000000 6636.000000000 6636.000000000
# mean     0.007890139           -0.000247330    8.961603779   85.744424352
# std      0.001155059            0.006082461   24.305376076   34.964558531
# min      0.006190750           -0.029769400    0.034114800    0.000000000
# 25%      0.006796250           -0.003340125    0.281765000  100.000000000
# 50%      0.007510000           -0.000451459    0.466375000  100.000000000
# 75%      0.009124188            0.002782650    4.672500000  100.000000000
# max      0.009716750            0.039151300  149.430000000  100.000000000
#
#                 dema            ema            rsi  standardDeviation  \
# count 6636.000000000 6636.000000000 6636.000000000     6636.000000000
# mean     8.961603779    8.961603779   51.235684147        0.000000000
# std     24.305376076   24.305376076   49.988495119        0.000000000
# min      0.034114800    0.034114800    0.000000000        0.000000000
# 25%      0.281765000    0.281765000    0.000000000        0.000000000
# 50%      0.466375000    0.466375000  100.000000000        0.000000000
# 75%      4.672500000    4.672500000  100.000000000        0.000000000
# max    149.430000000  149.430000000  100.000000000        0.000000000
#
#                 tema       williams            wma
# count 6636.000000000 6636.000000000 6636.000000000
# mean     8.961603779  -48.736724022    8.961603779
# std     24.305376076   30.902306970   24.305376076
# min      0.034114800 -100.000000000    0.034114800
# 25%      0.281765000  -76.778002468    0.281765000
# 50%      0.466375000  -48.046885496    0.466375000
# 75%      4.672500000  -20.002523340    4.672500000
# max    149.430000000    0.000000000  149.430000000

# %% [markdown]
# # Data Cleaning & Preprocessing

# %%
nvda_duplicates = nvda_data.duplicated()
print("Duplicate rows in your data: ")
nvda_duplicates.value_counts()
# Out:
# Duplicate rows in your data:
# False    6603
# True       37
# Name: count, dtype: int64

# %%
df_duplicates_rows = nvda_data[nvda_data.duplicated(keep=False)]

# Displaying examples of duplicated rows
df_duplicates_rows.head(10)
# Out:
#            date   NVDA_close    NVDA_high     NVDA_low    NVDA_open  \
# 124  20-07-1999 21.000000000 21.380000000 20.250000000 21.380000000
# 125  20-07-1999 21.000000000 21.380000000 20.250000000 21.380000000
# 188  18-10-1999 20.250000000 21.440000000 20.130000000 21.440000000
# 189  18-10-1999 20.250000000 21.440000000 20.130000000 21.440000000
# 376  14-07-2000 73.810000000 77.310000000 72.000000000 75.880000000
# 377  14-07-2000 73.810000000 77.310000000 72.000000000 75.880000000
# 502  10-01-2001 44.310000000 44.500000000 38.380000000 39.310000000
# 503  10-01-2001 44.310000000 44.500000000 38.380000000 39.310000000
# 565  10-04-2001 65.270000000 67.200000000 60.510000000 61.070000000
# 566  10-04-2001 65.270000000 67.200000000 60.510000000 61.070000000
#
#      NVDA_traded_volume  NVDA_adjClose  NVDA_adjLow  NVDA_adjOpen  \
# 124              372400    0.040126771  0.038693672   0.040852874
# 125              372400    0.040126771  0.038693672   0.040852874
# 188              448300    0.038693672  0.038464376   0.040967522
# 189              448300    0.038693672  0.038464376   0.040967522
# 376             1167500    0.282072092  0.275155001   0.289982798
# 377             1167500    0.282072092  0.275155001   0.289982798
# 502             1637200    0.169334974  0.146672902   0.150226987
# 503             1637200    0.169334974  0.146672902   0.150226987
# 565             4943400    0.249435652  0.231244849   0.233384943
# 566             4943400    0.249435652  0.231244849   0.233384943
#
#      NVDA_adj_traded_volume  NVDA_divCash  NVDA_splitFactor      sector  \
# 124               178751910   0.000000000       1.000000000         NaN
# 125               178751910   0.000000000       1.000000000         NaN
# 188               215183892   0.000000000       1.000000000         NaN
# 189               215183892   0.000000000       1.000000000         NaN
# 376               280199859   0.000000000       1.000000000  Technology
# 377               280199859   0.000000000       1.000000000  Technology
# 502               392927803   0.000000000       1.000000000  Technology
# 503               392927803   0.000000000       1.000000000  Technology
# 565              1186415406   0.000000000       1.000000000  Technology
# 566              1186415406   0.000000000       1.000000000  Technology
#
#     exchange           pe  basicMaterialsChangesPercentage  \
# 124      NaN          NaN                              NaN
# 125      NaN          NaN                              NaN
# 188      NaN          NaN                              NaN
# 189      NaN          NaN                              NaN
# 376   NASDAQ 97.384494220                              NaN
# 377   NASDAQ 97.384494220                              NaN
# 502   NASDAQ 51.613514490                              NaN
# 503   NASDAQ 51.613514490                              NaN
# 565   NASDAQ 30.714061410                              NaN
# 566   NASDAQ 30.714061410                              NaN
#
#      communicationServicesChangesPercentage  \
# 124                                     NaN
# 125                                     NaN
# 188                                     NaN
# 189                                     NaN
# 376                                     NaN
# 377                                     NaN
# 502                                     NaN
# 503                                     NaN
# 565                                     NaN
# 566                                     NaN
#
#      consumerCyclicalChangesPercentage  consumerDefensiveChangesPercentage  \
# 124                                NaN                                 NaN
# 125                                NaN                                 NaN
# 188                                NaN                                 NaN
# 189                                NaN                                 NaN
# 376                                NaN                                 NaN
# 377                                NaN                                 NaN
# 502                                NaN                                 NaN
# 503                                NaN                                 NaN
# 565                                NaN                                 NaN
# 566                                NaN                                 NaN
#
#      energyChangesPercentage  financialServicesChangesPercentage  \
# 124                      NaN                                 NaN
# 125                      NaN                                 NaN
# 188                      NaN                                 NaN
# 189                      NaN                                 NaN
# 376                      NaN                                 NaN
# 377                      NaN                                 NaN
# 502                      NaN                                 NaN
# 503                      NaN                                 NaN
# 565                      NaN                                 NaN
# 566                      NaN                                 NaN
#
#      healthcareChangesPercentage  industrialsChangesPercentage  \
# 124                          NaN                           NaN
# 125                          NaN                           NaN
# 188                          NaN                           NaN
# 189                          NaN                           NaN
# 376                          NaN                           NaN
# 377                          NaN                           NaN
# 502                          NaN                           NaN
# 503                          NaN                           NaN
# 565                          NaN                           NaN
# 566                          NaN                           NaN
#
#      realEstateChangesPercentage  technologyChangesPercentage  \
# 124                          NaN                          NaN
# 125                          NaN                          NaN
# 188                          NaN                          NaN
# 189                          NaN                          NaN
# 376                          NaN                          NaN
# 377                          NaN                          NaN
# 502                          NaN                          NaN
# 503                          NaN                          NaN
# 565                          NaN                          NaN
# 566                          NaN                          NaN
#
#      utilitiesChangesPercentage  month1  month2      month3      month6  \
# 124                         NaN     NaN     NaN 4.640000000 4.640000000
# 125                         NaN     NaN     NaN 4.640000000 4.640000000
# 188                         NaN     NaN     NaN 5.150000000 5.210000000
# 189                         NaN     NaN     NaN 5.150000000 5.210000000
# 376                         NaN     NaN     NaN 6.170000000 6.280000000
# 377                         NaN     NaN     NaN 6.170000000 6.280000000
# 502                         NaN     NaN     NaN 5.290000000 5.160000000
# 503                         NaN     NaN     NaN 5.290000000 5.160000000
# 565                         NaN     NaN     NaN 3.940000000 4.000000000
# 566                         NaN     NaN     NaN 3.940000000 4.000000000
#
#           year1       year2       year3       year5       year7      year10  \
# 124 4.960000000 5.430000000 5.480000000 5.540000000 5.800000000 5.650000000
# 125 4.960000000 5.430000000 5.480000000 5.540000000 5.800000000 5.650000000
# 188 5.420000000 5.850000000 5.920000000 6.030000000 6.340000000 6.120000000
# 189 5.420000000 5.850000000 5.920000000 6.030000000 6.340000000 6.120000000
# 376 6.120000000 6.410000000 6.350000000 6.250000000 6.290000000 6.100000000
# 377 6.120000000 6.410000000 6.350000000 6.250000000 6.290000000 6.100000000
# 502 4.820000000 4.760000000 4.780000000 4.830000000 5.090000000 5.100000000
# 503 4.820000000 4.760000000 4.780000000 4.830000000 5.090000000 5.100000000
# 565 4.040000000 4.240000000 4.400000000 4.700000000 4.990000000 5.090000000
# 566 4.040000000 4.240000000 4.400000000 4.700000000 4.990000000 5.090000000
#
#          year20      year30  inflationRate  Palladium_price  Palladium_volume  \
# 124 6.180000000 5.890000000            NaN    338.500000000      65.000000000
# 125 6.180000000 5.890000000            NaN    338.500000000      65.000000000
# 188 6.690000000 6.300000000            NaN    375.000000000     137.000000000
# 189 6.690000000 6.300000000            NaN    375.000000000     137.000000000
# 376 6.240000000 5.880000000            NaN    686.650000000     176.000000000
# 377 6.240000000 5.880000000            NaN    686.650000000     176.000000000
# 502 5.600000000 5.490000000            NaN   1072.800000000      99.000000000
# 503 5.600000000 5.490000000            NaN   1072.800000000      99.000000000
# 565 5.760000000 5.630000000            NaN    678.000000000      64.000000000
# 566 5.760000000 5.630000000            NaN    678.000000000      64.000000000
#
#      Palladium_open  Palladium_close  Copper_price   Copper_volume  \
# 124   336.750000000    338.500000000   0.769500000 14313.000000000
# 125   336.750000000    338.500000000   0.769500000 14313.000000000
# 188   377.000000000    375.000000000   0.796000000  7905.000000000
# 189   377.000000000    375.000000000   0.796000000  7905.000000000
# 376   673.000000000    686.650000000   0.829000000 16963.000000000
# 377   673.000000000    686.650000000   0.829000000 16963.000000000
# 502  1042.000000000   1072.800000000   0.826000000  7581.000000000
# 503  1042.000000000   1072.800000000   0.826000000  7581.000000000
# 565   672.000000000    678.000000000   0.769500000 19880.000000000
# 566   672.000000000    678.000000000   0.769500000 19880.000000000
#
#      Copper_open  Copper_close  Lithium_price  Lithium_volume  Lithium_open  \
# 124  0.781000000   0.769500000            NaN             NaN           NaN
# 125  0.781000000   0.769500000            NaN             NaN           NaN
# 188  0.783000000   0.796000000            NaN             NaN           NaN
# 189  0.783000000   0.796000000            NaN             NaN           NaN
# 376  0.829500000   0.829000000            NaN             NaN           NaN
# 377  0.829500000   0.829000000            NaN             NaN           NaN
# 502  0.825000000   0.826000000            NaN             NaN           NaN
# 503  0.825000000   0.826000000            NaN             NaN           NaN
# 565  0.760000000   0.769500000            NaN             NaN           NaN
# 566  0.760000000   0.769500000            NaN             NaN           NaN
#
#      Lithium_close  Silver_price  Silver_volume  Silver_open  Silver_close  \
# 124            NaN   5.060000000    0.000000000  5.040000000   5.060000000
# 125            NaN   5.060000000    0.000000000  5.040000000   5.060000000
# 188            NaN   5.240000000    0.000000000  5.335000000   5.240000000
# 189            NaN   5.240000000    0.000000000  5.335000000   5.240000000
# 376            NaN   5.000000000    0.000000000  4.970000000   5.000000000
# 377            NaN   5.000000000    0.000000000  4.970000000   5.000000000
# 502            NaN   4.550000000    0.000000000  4.555000000   4.550000000
# 503            NaN   4.550000000    0.000000000  4.555000000   4.550000000
# 565            NaN   4.330000000    0.000000000  4.330000000   4.330000000
# 566            NaN   4.330000000    0.000000000  4.330000000   4.330000000
#
#        Gold_price  Gold_volume     Gold_open    Gold_close  CADUSD_open  \
# 124 253.350000000  0.000000000 253.250000000 253.350000000          NaN
# 125 253.350000000  0.000000000 253.250000000 253.350000000          NaN
# 188 311.500000000  0.000000000 316.000000000 311.500000000          NaN
# 189 311.500000000  0.000000000 316.000000000 311.500000000          NaN
# 376 281.300000000  0.000000000 280.500000000 281.300000000          NaN
# 377 281.300000000  0.000000000 280.500000000 281.300000000          NaN
# 502 264.950000000  0.000000000 267.750000000 264.950000000          NaN
# 503 264.950000000  0.000000000 267.750000000 264.950000000          NaN
# 565 257.650000000  0.000000000 258.550000000 257.650000000          NaN
# 566 257.650000000  0.000000000 258.550000000 257.650000000          NaN
#
#      CADUSD_high  CADUSD_low  CADUSD_close  CADUSD_adjClose  \
# 124          NaN         NaN           NaN              NaN
# 125          NaN         NaN           NaN              NaN
# 188          NaN         NaN           NaN              NaN
# 189          NaN         NaN           NaN              NaN
# 376          NaN         NaN           NaN              NaN
# 377          NaN         NaN           NaN              NaN
# 502          NaN         NaN           NaN              NaN
# 503          NaN         NaN           NaN              NaN
# 565          NaN         NaN           NaN              NaN
# 566          NaN         NaN           NaN              NaN
#
#      CADUSD_traded_volume  CADUSD_unadjusted_traded_Volume  CADUSD_change  \
# 124                   NaN                              NaN            NaN
# 125                   NaN                              NaN            NaN
# 188                   NaN                              NaN            NaN
# 189                   NaN                              NaN            NaN
# 376                   NaN                              NaN            NaN
# 377                   NaN                              NaN            NaN
# 502                   NaN                              NaN            NaN
# 503                   NaN                              NaN            NaN
# 565                   NaN                              NaN            NaN
# 566                   NaN                              NaN            NaN
#
#      CADUSD_changePercent  CADUSD_vwap CADUSD_label  CADUSD_changeOverTime  \
# 124                   NaN          NaN          NaN                    NaN
# 125                   NaN          NaN          NaN                    NaN
# 188                   NaN          NaN          NaN                    NaN
# 189                   NaN          NaN          NaN                    NaN
# 376                   NaN          NaN          NaN                    NaN
# 377                   NaN          NaN          NaN                    NaN
# 502                   NaN          NaN          NaN                    NaN
# 503                   NaN          NaN          NaN                    NaN
# 565                   NaN          NaN          NaN                    NaN
# 566                   NaN          NaN          NaN                    NaN
#
#      CHFUSD_open  CHFUSD_high  CHFUSD_low  CHFUSD_close  CHFUSD_adjClose  \
# 124          NaN          NaN         NaN           NaN              NaN
# 125          NaN          NaN         NaN           NaN              NaN
# 188          NaN          NaN         NaN           NaN              NaN
# 189          NaN          NaN         NaN           NaN              NaN
# 376          NaN          NaN         NaN           NaN              NaN
# 377          NaN          NaN         NaN           NaN              NaN
# 502          NaN          NaN         NaN           NaN              NaN
# 503          NaN          NaN         NaN           NaN              NaN
# 565          NaN          NaN         NaN           NaN              NaN
# 566          NaN          NaN         NaN           NaN              NaN
#
#      CHFUSD_traded_volume  CHFUSD_unadjusted_traded_Volume  CHFUSD_change  \
# 124                   NaN                              NaN            NaN
# 125                   NaN                              NaN            NaN
# 188                   NaN                              NaN            NaN
# 189                   NaN                              NaN            NaN
# 376                   NaN                              NaN            NaN
# 377                   NaN                              NaN            NaN
# 502                   NaN                              NaN            NaN
# 503                   NaN                              NaN            NaN
# 565                   NaN                              NaN            NaN
# 566                   NaN                              NaN            NaN
#
#      CHFUSD_changePercent  CHFUSD_vwap CHFUSD_label  CHFUSD_changeOverTime  \
# 124                   NaN          NaN          NaN                    NaN
# 125                   NaN          NaN          NaN                    NaN
# 188                   NaN          NaN          NaN                    NaN
# 189                   NaN          NaN          NaN                    NaN
# 376                   NaN          NaN          NaN                    NaN
# 377                   NaN          NaN          NaN                    NaN
# 502                   NaN          NaN          NaN                    NaN
# 503                   NaN          NaN          NaN                    NaN
# 565                   NaN          NaN          NaN                    NaN
# 566                   NaN          NaN          NaN                    NaN
#
#      CNHUSD_open  CNHUSD_high  CNHUSD_low  CNHUSD_close  CNHUSD_adjClose  \
# 124          NaN          NaN         NaN           NaN              NaN
# 125          NaN          NaN         NaN           NaN              NaN
# 188          NaN          NaN         NaN           NaN              NaN
# 189          NaN          NaN         NaN           NaN              NaN
# 376          NaN          NaN         NaN           NaN              NaN
# 377          NaN          NaN         NaN           NaN              NaN
# 502          NaN          NaN         NaN           NaN              NaN
# 503          NaN          NaN         NaN           NaN              NaN
# 565          NaN          NaN         NaN           NaN              NaN
# 566          NaN          NaN         NaN           NaN              NaN
#
#      CNHUSD_traded_volume  CNHUSD_unadjusted_traded_Volume  CNHUSD_change  \
# 124                   NaN                              NaN            NaN
# 125                   NaN                              NaN            NaN
# 188                   NaN                              NaN            NaN
# 189                   NaN                              NaN            NaN
# 376                   NaN                              NaN            NaN
# 377                   NaN                              NaN            NaN
# 502                   NaN                              NaN            NaN
# 503                   NaN                              NaN            NaN
# 565                   NaN                              NaN            NaN
# 566                   NaN                              NaN            NaN
#
#      CNHUSD_changePercent  CNHUSD_vwap CNHUSD_label  CNHUSD_changeOverTime  \
# 124                   NaN          NaN          NaN                    NaN
# 125                   NaN          NaN          NaN                    NaN
# 188                   NaN          NaN          NaN                    NaN
# 189                   NaN          NaN          NaN                    NaN
# 376                   NaN          NaN          NaN                    NaN
# 377                   NaN          NaN          NaN                    NaN
# 502                   NaN          NaN          NaN                    NaN
# 503                   NaN          NaN          NaN                    NaN
# 565                   NaN          NaN          NaN                    NaN
# 566                   NaN          NaN          NaN                    NaN
#
#      KRWUSD_open  KRWUSD_high  KRWUSD_low  KRWUSD_close  KRWUSD_adjClose  \
# 124          NaN          NaN         NaN           NaN              NaN
# 125          NaN          NaN         NaN           NaN              NaN
# 188          NaN          NaN         NaN           NaN              NaN
# 189          NaN          NaN         NaN           NaN              NaN
# 376          NaN          NaN         NaN           NaN              NaN
# 377          NaN          NaN         NaN           NaN              NaN
# 502          NaN          NaN         NaN           NaN              NaN
# 503          NaN          NaN         NaN           NaN              NaN
# 565          NaN          NaN         NaN           NaN              NaN
# 566          NaN          NaN         NaN           NaN              NaN
#
#      KRWUSD_traded_volume  KRWUSD_unadjusted_traded_Volume  KRWUSD_change  \
# 124                   NaN                              NaN            NaN
# 125                   NaN                              NaN            NaN
# 188                   NaN                              NaN            NaN
# 189                   NaN                              NaN            NaN
# 376                   NaN                              NaN            NaN
# 377                   NaN                              NaN            NaN
# 502                   NaN                              NaN            NaN
# 503                   NaN                              NaN            NaN
# 565                   NaN                              NaN            NaN
# 566                   NaN                              NaN            NaN
#
#      KRWUSD_changePercent  KRWUSD_vwap KRWUSD_label  KRWUSD_changeOverTime  \
# 124                   NaN          NaN          NaN                    NaN
# 125                   NaN          NaN          NaN                    NaN
# 188                   NaN          NaN          NaN                    NaN
# 189                   NaN          NaN          NaN                    NaN
# 376                   NaN          NaN          NaN                    NaN
# 377                   NaN          NaN          NaN                    NaN
# 502                   NaN          NaN          NaN                    NaN
# 503                   NaN          NaN          NaN                    NaN
# 565                   NaN          NaN          NaN                    NaN
# 566                   NaN          NaN          NaN                    NaN
#
#      EURUSD_open  EURUSD_high  EURUSD_low  EURUSD_close  EURUSD_adjClose  \
# 124          NaN          NaN         NaN           NaN              NaN
# 125          NaN          NaN         NaN           NaN              NaN
# 188          NaN          NaN         NaN           NaN              NaN
# 189          NaN          NaN         NaN           NaN              NaN
# 376          NaN          NaN         NaN           NaN              NaN
# 377          NaN          NaN         NaN           NaN              NaN
# 502          NaN          NaN         NaN           NaN              NaN
# 503          NaN          NaN         NaN           NaN              NaN
# 565          NaN          NaN         NaN           NaN              NaN
# 566          NaN          NaN         NaN           NaN              NaN
#
#      EURUSD_traded_volume  EURUSD_unadjusted_traded_Volume  EURUSD_change  \
# 124                   NaN                              NaN            NaN
# 125                   NaN                              NaN            NaN
# 188                   NaN                              NaN            NaN
# 189                   NaN                              NaN            NaN
# 376                   NaN                              NaN            NaN
# 377                   NaN                              NaN            NaN
# 502                   NaN                              NaN            NaN
# 503                   NaN                              NaN            NaN
# 565                   NaN                              NaN            NaN
# 566                   NaN                              NaN            NaN
#
#      EURUSD_changePercent  EURUSD_vwap EURUSD_label  EURUSD_changeOverTime  \
# 124                   NaN          NaN          NaN                    NaN
# 125                   NaN          NaN          NaN                    NaN
# 188                   NaN          NaN          NaN                    NaN
# 189                   NaN          NaN          NaN                    NaN
# 376                   NaN          NaN          NaN                    NaN
# 377                   NaN          NaN          NaN                    NaN
# 502                   NaN          NaN          NaN                    NaN
# 503                   NaN          NaN          NaN                    NaN
# 565                   NaN          NaN          NaN                    NaN
# 566                   NaN          NaN          NaN                    NaN
#
#      GBPUSD_open  GBPUSD_high  GBPUSD_low  GBPUSD_close  GBPUSD_adjClose  \
# 124          NaN          NaN         NaN           NaN              NaN
# 125          NaN          NaN         NaN           NaN              NaN
# 188          NaN          NaN         NaN           NaN              NaN
# 189          NaN          NaN         NaN           NaN              NaN
# 376          NaN          NaN         NaN           NaN              NaN
# 377          NaN          NaN         NaN           NaN              NaN
# 502          NaN          NaN         NaN           NaN              NaN
# 503          NaN          NaN         NaN           NaN              NaN
# 565          NaN          NaN         NaN           NaN              NaN
# 566          NaN          NaN         NaN           NaN              NaN
#
#      GBPUSD_traded_volume  GBPUSD_unadjusted_traded_Volume  GBPUSD_change  \
# 124                   NaN                              NaN            NaN
# 125                   NaN                              NaN            NaN
# 188                   NaN                              NaN            NaN
# 189                   NaN                              NaN            NaN
# 376                   NaN                              NaN            NaN
# 377                   NaN                              NaN            NaN
# 502                   NaN                              NaN            NaN
# 503                   NaN                              NaN            NaN
# 565                   NaN                              NaN            NaN
# 566                   NaN                              NaN            NaN
#
#      GBPUSD_changePercent  GBPUSD_vwap GBPUSD_label  GBPUSD_changeOverTime  \
# 124                   NaN          NaN          NaN                    NaN
# 125                   NaN          NaN          NaN                    NaN
# 188                   NaN          NaN          NaN                    NaN
# 189                   NaN          NaN          NaN                    NaN
# 376                   NaN          NaN          NaN                    NaN
# 377                   NaN          NaN          NaN                    NaN
# 502                   NaN          NaN          NaN                    NaN
# 503                   NaN          NaN          NaN                    NaN
# 565                   NaN          NaN          NaN                    NaN
# 566                   NaN          NaN          NaN                    NaN
#
#      JPYUSD_open  JPYUSD_high  JPYUSD_low  JPYUSD_close  JPYUSD_adjClose  \
# 124          NaN          NaN         NaN           NaN              NaN
# 125          NaN          NaN         NaN           NaN              NaN
# 188          NaN          NaN         NaN           NaN              NaN
# 189          NaN          NaN         NaN           NaN              NaN
# 376          NaN          NaN         NaN           NaN              NaN
# 377          NaN          NaN         NaN           NaN              NaN
# 502          NaN          NaN         NaN           NaN              NaN
# 503          NaN          NaN         NaN           NaN              NaN
# 565          NaN          NaN         NaN           NaN              NaN
# 566          NaN          NaN         NaN           NaN              NaN
#
#      JPYUSD_traded_volume  JPYUSD_unadjusted_traded_Volume  JPYUSD_change  \
# 124                   NaN                              NaN            NaN
# 125                   NaN                              NaN            NaN
# 188                   NaN                              NaN            NaN
# 189                   NaN                              NaN            NaN
# 376                   NaN                              NaN            NaN
# 377                   NaN                              NaN            NaN
# 502                   NaN                              NaN            NaN
# 503                   NaN                              NaN            NaN
# 565                   NaN                              NaN            NaN
# 566                   NaN                              NaN            NaN
#
#      JPYUSD_changePercent  JPYUSD_vwap JPYUSD_label  JPYUSD_changeOverTime  \
# 124                   NaN          NaN          NaN                    NaN
# 125                   NaN          NaN          NaN                    NaN
# 188                   NaN          NaN          NaN                    NaN
# 189                   NaN          NaN          NaN                    NaN
# 376                   NaN          NaN          NaN                    NaN
# 377                   NaN          NaN          NaN                    NaN
# 502                   NaN          NaN          NaN                    NaN
# 503                   NaN          NaN          NaN                    NaN
# 565                   NaN          NaN          NaN                    NaN
# 566                   NaN          NaN          NaN                    NaN
#
#     symbol         sma           adx        dema         ema           rsi  \
# 124   NVDA 0.043750200 100.000000000 0.043750200 0.043750200   0.000000000
# 125   NVDA 0.043750200 100.000000000 0.043750200 0.043750200   0.000000000
# 188   NVDA 0.042187700 100.000000000 0.042187700 0.042187700   0.000000000
# 189   NVDA 0.042187700 100.000000000 0.042187700 0.042187700   0.000000000
# 376   NVDA 0.307550000 100.000000000 0.307550000 0.307550000   0.000000000
# 377   NVDA 0.307550000 100.000000000 0.307550000 0.307550000   0.000000000
# 502   NVDA 0.184640000 100.000000000 0.184640000 0.184640000 100.000000000
# 503   NVDA 0.184640000 100.000000000 0.184640000 0.184640000 100.000000000
# 565   NVDA 0.271960000 100.000000000 0.271960000 0.271960000 100.000000000
# 566   NVDA 0.271960000 100.000000000 0.271960000 0.271960000 100.000000000
#
#      standardDeviation        tema      williams         wma  \
# 124        0.000000000 0.043750200 -33.334755525 0.043750200
# 125        0.000000000 0.043750200 -33.334755525 0.043750200
# 188        0.000000000 0.042187700 -90.476887068 0.042187700
# 189        0.000000000 0.042187700 -90.476887068 0.042187700
# 376        0.000000000 0.307550000 -65.898825655 0.307550000
# 377        0.000000000 0.307550000 -65.898825655 0.307550000
# 502        0.000000000 0.184640000  -3.056426332 0.184640000
# 503        0.000000000 0.184640000  -3.056426332 0.184640000
# 565        0.000000000 0.271960000 -28.848223897 0.271960000
# 566        0.000000000 0.271960000 -28.848223897 0.271960000
#
#     NVDA_stock_news_sentiment NVDA_press_release_sentiment  \
# 124                   neutral                      neutral
# 125                   neutral                      neutral
# 188                   neutral                      neutral
# 189                   neutral                      neutral
# 376                   neutral                      neutral
# 377                   neutral                      neutral
# 502                   neutral                      neutral
# 503                   neutral                      neutral
# 565                   neutral                      neutral
# 566                   neutral                      neutral
#
#     NVDA_twitter_social_sentiment
# 124                           NaN
# 125                           NaN
# 188                           NaN
# 189                           NaN
# 376                           NaN
# 377                           NaN
# 502                           NaN
# 503                           NaN
# 565                           NaN
# 566                           NaN

# %%
# dropping all duplicates
nvda_data = nvda_data.drop_duplicates()

# converting date column to datetime
nvda_data['date'] = pd.to_datetime(nvda_data['date'], format="%d-%m-%Y")

# %%
nvda_data.head()
# Out:
#         date   NVDA_close    NVDA_high     NVDA_low    NVDA_open  \
# 0 1999-01-22 19.690000000 23.440000000 18.630000000 21.000000000
# 1 1999-01-25 21.750000000 22.000000000 19.690000000 21.250000000
# 2 1999-01-26 20.060000000 22.440000000 19.750000000 22.000000000
# 3 1999-01-27 20.000000000 20.630000000 19.000000000 20.130000000
# 4 1999-01-28 19.940000000 20.130000000 19.810000000 20.000000000
#
#    NVDA_traded_volume  NVDA_adjClose  NVDA_adjLow  NVDA_adjOpen  \
# 0             5655600    0.037623625  0.035598178   0.040126771
# 1             1063500    0.041559870  0.037623625   0.040604471
# 2              715000    0.038330620  0.037738273   0.042037570
# 3              509100    0.038215972  0.036305174   0.038464376
# 4              474000    0.038101324  0.037852921   0.038215972
#
#    NVDA_adj_traded_volume  NVDA_divCash  NVDA_splitFactor sector exchange  pe  \
# 0              2714686642   0.000000000       1.000000000    NaN      NaN NaN
# 1               510479744   0.000000000       1.000000000    NaN      NaN NaN
# 2               343199828   0.000000000       1.000000000    NaN      NaN NaN
# 3               244367877   0.000000000       1.000000000    NaN      NaN NaN
# 4               227519886   0.000000000       1.000000000    NaN      NaN NaN
#
#    basicMaterialsChangesPercentage  communicationServicesChangesPercentage  \
# 0                              NaN                                     NaN
# 1                              NaN                                     NaN
# 2                              NaN                                     NaN
# 3                              NaN                                     NaN
# 4                              NaN                                     NaN
#
#    consumerCyclicalChangesPercentage  consumerDefensiveChangesPercentage  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# 2                                NaN                                 NaN
# 3                                NaN                                 NaN
# 4                                NaN                                 NaN
#
#    energyChangesPercentage  financialServicesChangesPercentage  \
# 0                      NaN                                 NaN
# 1                      NaN                                 NaN
# 2                      NaN                                 NaN
# 3                      NaN                                 NaN
# 4                      NaN                                 NaN
#
#    healthcareChangesPercentage  industrialsChangesPercentage  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                          NaN                           NaN
#
#    realEstateChangesPercentage  technologyChangesPercentage  \
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3                          NaN                          NaN
# 4                          NaN                          NaN
#
#    utilitiesChangesPercentage  month1  month2      month3      month6  \
# 0                         NaN     NaN     NaN 4.360000000 4.440000000
# 1                         NaN     NaN     NaN 4.440000000 4.450000000
# 2                         NaN     NaN     NaN 4.460000000 4.460000000
# 3                         NaN     NaN     NaN 4.470000000 4.470000000
# 4                         NaN     NaN     NaN 4.490000000 4.450000000
#
#         year1       year2       year3       year5       year7      year10  \
# 0 4.460000000 4.590000000 4.580000000 4.540000000 4.730000000 4.640000000
# 1 4.480000000 4.590000000 4.580000000 4.550000000 4.740000000 4.670000000
# 2 4.510000000 4.630000000 4.610000000 4.580000000 4.760000000 4.690000000
# 3 4.510000000 4.570000000 4.570000000 4.570000000 4.740000000 4.680000000
# 4 4.520000000 4.580000000 4.570000000 4.570000000 4.730000000 4.670000000
#
#        year20      year30  inflationRate  Palladium_price  Palladium_volume  \
# 0 5.380000000 5.090000000            NaN    321.050000000      38.000000000
# 1 5.400000000 5.120000000            NaN    325.000000000     127.000000000
# 2 5.410000000 5.120000000            NaN    326.750000000      27.000000000
# 3 5.400000000 5.140000000            NaN    329.000000000      63.000000000
# 4 5.370000000 5.110000000            NaN    331.750000000      31.000000000
#
#    Palladium_open  Palladium_close  Copper_price  Copper_volume  Copper_open  \
# 0   320.000000000    321.050000000   0.657000000 6178.000000000  0.658500000
# 1   321.050000000    325.000000000   0.653500000 5340.000000000  0.652000000
# 2   325.500000000    326.750000000   0.649500000 7328.000000000  0.654000000
# 3   329.000000000    329.000000000   0.644000000 3401.000000000  0.643000000
# 4   328.550000000    331.750000000   0.643500000 8454.000000000  0.644000000
#
#    Copper_close  Lithium_price  Lithium_volume  Lithium_open  Lithium_close  \
# 0   0.657000000            NaN             NaN           NaN            NaN
# 1   0.653500000            NaN             NaN           NaN            NaN
# 2   0.649500000            NaN             NaN           NaN            NaN
# 3   0.644000000            NaN             NaN           NaN            NaN
# 4   0.643500000            NaN             NaN           NaN            NaN
#
#    Silver_price  Silver_volume  Silver_open  Silver_close    Gold_price  \
# 0   5.115000000    0.000000000  5.115000000   5.115000000 286.450000000
# 1   5.185000000    0.000000000  5.100000000   5.185000000 287.850000000
# 2   5.115000000    0.000000000  5.175000000   5.115000000 286.150000000
# 3   5.095000000    0.000000000  5.115000000   5.095000000 283.000000000
# 4   5.235000000    0.000000000  5.100000000   5.235000000 284.250000000
#
#    Gold_volume     Gold_open    Gold_close  CADUSD_open  CADUSD_high  \
# 0  0.000000000 287.450000000 286.450000000          NaN          NaN
# 1  0.000000000 286.450000000 287.850000000          NaN          NaN
# 2  0.000000000 287.750000000 286.150000000          NaN          NaN
# 3  0.000000000 285.950000000 283.000000000          NaN          NaN
# 4  0.000000000 282.850000000 284.250000000          NaN          NaN
#
#    CADUSD_low  CADUSD_close  CADUSD_adjClose  CADUSD_traded_volume  \
# 0         NaN           NaN              NaN                   NaN
# 1         NaN           NaN              NaN                   NaN
# 2         NaN           NaN              NaN                   NaN
# 3         NaN           NaN              NaN                   NaN
# 4         NaN           NaN              NaN                   NaN
#
#    CADUSD_unadjusted_traded_Volume  CADUSD_change  CADUSD_changePercent  \
# 0                              NaN            NaN                   NaN
# 1                              NaN            NaN                   NaN
# 2                              NaN            NaN                   NaN
# 3                              NaN            NaN                   NaN
# 4                              NaN            NaN                   NaN
#
#    CADUSD_vwap CADUSD_label  CADUSD_changeOverTime  CHFUSD_open  CHFUSD_high  \
# 0          NaN          NaN                    NaN          NaN          NaN
# 1          NaN          NaN                    NaN          NaN          NaN
# 2          NaN          NaN                    NaN          NaN          NaN
# 3          NaN          NaN                    NaN          NaN          NaN
# 4          NaN          NaN                    NaN          NaN          NaN
#
#    CHFUSD_low  CHFUSD_close  CHFUSD_adjClose  CHFUSD_traded_volume  \
# 0         NaN           NaN              NaN                   NaN
# 1         NaN           NaN              NaN                   NaN
# 2         NaN           NaN              NaN                   NaN
# 3         NaN           NaN              NaN                   NaN
# 4         NaN           NaN              NaN                   NaN
#
#    CHFUSD_unadjusted_traded_Volume  CHFUSD_change  CHFUSD_changePercent  \
# 0                              NaN            NaN                   NaN
# 1                              NaN            NaN                   NaN
# 2                              NaN            NaN                   NaN
# 3                              NaN            NaN                   NaN
# 4                              NaN            NaN                   NaN
#
#    CHFUSD_vwap CHFUSD_label  CHFUSD_changeOverTime  CNHUSD_open  CNHUSD_high  \
# 0          NaN          NaN                    NaN          NaN          NaN
# 1          NaN          NaN                    NaN          NaN          NaN
# 2          NaN          NaN                    NaN          NaN          NaN
# 3          NaN          NaN                    NaN          NaN          NaN
# 4          NaN          NaN                    NaN          NaN          NaN
#
#    CNHUSD_low  CNHUSD_close  CNHUSD_adjClose  CNHUSD_traded_volume  \
# 0         NaN           NaN              NaN                   NaN
# 1         NaN           NaN              NaN                   NaN
# 2         NaN           NaN              NaN                   NaN
# 3         NaN           NaN              NaN                   NaN
# 4         NaN           NaN              NaN                   NaN
#
#    CNHUSD_unadjusted_traded_Volume  CNHUSD_change  CNHUSD_changePercent  \
# 0                              NaN            NaN                   NaN
# 1                              NaN            NaN                   NaN
# 2                              NaN            NaN                   NaN
# 3                              NaN            NaN                   NaN
# 4                              NaN            NaN                   NaN
#
#    CNHUSD_vwap CNHUSD_label  CNHUSD_changeOverTime  KRWUSD_open  KRWUSD_high  \
# 0          NaN          NaN                    NaN          NaN          NaN
# 1          NaN          NaN                    NaN          NaN          NaN
# 2          NaN          NaN                    NaN          NaN          NaN
# 3          NaN          NaN                    NaN          NaN          NaN
# 4          NaN          NaN                    NaN          NaN          NaN
#
#    KRWUSD_low  KRWUSD_close  KRWUSD_adjClose  KRWUSD_traded_volume  \
# 0         NaN           NaN              NaN                   NaN
# 1         NaN           NaN              NaN                   NaN
# 2         NaN           NaN              NaN                   NaN
# 3         NaN           NaN              NaN                   NaN
# 4         NaN           NaN              NaN                   NaN
#
#    KRWUSD_unadjusted_traded_Volume  KRWUSD_change  KRWUSD_changePercent  \
# 0                              NaN            NaN                   NaN
# 1                              NaN            NaN                   NaN
# 2                              NaN            NaN                   NaN
# 3                              NaN            NaN                   NaN
# 4                              NaN            NaN                   NaN
#
#    KRWUSD_vwap KRWUSD_label  KRWUSD_changeOverTime  EURUSD_open  EURUSD_high  \
# 0          NaN          NaN                    NaN          NaN          NaN
# 1          NaN          NaN                    NaN          NaN          NaN
# 2          NaN          NaN                    NaN          NaN          NaN
# 3          NaN          NaN                    NaN          NaN          NaN
# 4          NaN          NaN                    NaN          NaN          NaN
#
#    EURUSD_low  EURUSD_close  EURUSD_adjClose  EURUSD_traded_volume  \
# 0         NaN           NaN              NaN                   NaN
# 1         NaN           NaN              NaN                   NaN
# 2         NaN           NaN              NaN                   NaN
# 3         NaN           NaN              NaN                   NaN
# 4         NaN           NaN              NaN                   NaN
#
#    EURUSD_unadjusted_traded_Volume  EURUSD_change  EURUSD_changePercent  \
# 0                              NaN            NaN                   NaN
# 1                              NaN            NaN                   NaN
# 2                              NaN            NaN                   NaN
# 3                              NaN            NaN                   NaN
# 4                              NaN            NaN                   NaN
#
#    EURUSD_vwap EURUSD_label  EURUSD_changeOverTime  GBPUSD_open  GBPUSD_high  \
# 0          NaN          NaN                    NaN          NaN          NaN
# 1          NaN          NaN                    NaN          NaN          NaN
# 2          NaN          NaN                    NaN          NaN          NaN
# 3          NaN          NaN                    NaN          NaN          NaN
# 4          NaN          NaN                    NaN          NaN          NaN
#
#    GBPUSD_low  GBPUSD_close  GBPUSD_adjClose  GBPUSD_traded_volume  \
# 0         NaN           NaN              NaN                   NaN
# 1         NaN           NaN              NaN                   NaN
# 2         NaN           NaN              NaN                   NaN
# 3         NaN           NaN              NaN                   NaN
# 4         NaN           NaN              NaN                   NaN
#
#    GBPUSD_unadjusted_traded_Volume  GBPUSD_change  GBPUSD_changePercent  \
# 0                              NaN            NaN                   NaN
# 1                              NaN            NaN                   NaN
# 2                              NaN            NaN                   NaN
# 3                              NaN            NaN                   NaN
# 4                              NaN            NaN                   NaN
#
#    GBPUSD_vwap GBPUSD_label  GBPUSD_changeOverTime  JPYUSD_open  JPYUSD_high  \
# 0          NaN          NaN                    NaN          NaN          NaN
# 1          NaN          NaN                    NaN          NaN          NaN
# 2          NaN          NaN                    NaN          NaN          NaN
# 3          NaN          NaN                    NaN          NaN          NaN
# 4          NaN          NaN                    NaN          NaN          NaN
#
#    JPYUSD_low  JPYUSD_close  JPYUSD_adjClose  JPYUSD_traded_volume  \
# 0         NaN           NaN              NaN                   NaN
# 1         NaN           NaN              NaN                   NaN
# 2         NaN           NaN              NaN                   NaN
# 3         NaN           NaN              NaN                   NaN
# 4         NaN           NaN              NaN                   NaN
#
#    JPYUSD_unadjusted_traded_Volume  JPYUSD_change  JPYUSD_changePercent  \
# 0                              NaN            NaN                   NaN
# 1                              NaN            NaN                   NaN
# 2                              NaN            NaN                   NaN
# 3                              NaN            NaN                   NaN
# 4                              NaN            NaN                   NaN
#
#    JPYUSD_vwap JPYUSD_label  JPYUSD_changeOverTime symbol         sma  \
# 0          NaN          NaN                    NaN    NaN         NaN
# 1          NaN          NaN                    NaN    NaN         NaN
# 2          NaN          NaN                    NaN   NVDA 0.041797100
# 3          NaN          NaN                    NaN   NVDA 0.041666900
# 4          NaN          NaN                    NaN   NVDA 0.041536700
#
#             adx        dema         ema         rsi  standardDeviation  \
# 0           NaN         NaN         NaN         NaN                NaN
# 1           NaN         NaN         NaN         NaN                NaN
# 2 100.000000000 0.041797100 0.041797100 0.000000000        0.000000000
# 3 100.000000000 0.041666900 0.041666900 0.000000000        0.000000000
# 4   0.000000000 0.041536700 0.041536700 0.000000000        0.000000000
#
#          tema      williams         wma NVDA_stock_news_sentiment  \
# 0         NaN           NaN         NaN                   neutral
# 1         NaN           NaN         NaN                   neutral
# 2 0.041797100 -88.371137703 0.041797100                   neutral
# 3 0.041666900 -38.461084035 0.041666900                   neutral
# 4 0.041536700 -59.990784826 0.041536700                   neutral
#
#   NVDA_press_release_sentiment NVDA_twitter_social_sentiment
# 0                      neutral                           NaN
# 1                      neutral                           NaN
# 2                      neutral                           NaN
# 3                      neutral                           NaN
# 4                      neutral                           NaN

# %%
nvda_data.columns
# Out:
# Index(['date', 'NVDA_close', 'NVDA_high', 'NVDA_low', 'NVDA_open',
#        'NVDA_traded_volume', 'NVDA_adjClose', 'NVDA_adjLow', 'NVDA_adjOpen',
#        'NVDA_adj_traded_volume',
#        ...
#        'dema', 'ema', 'rsi', 'standardDeviation', 'tema', 'williams', 'wma',
#        'NVDA_stock_news_sentiment', 'NVDA_press_release_sentiment',
#        'NVDA_twitter_social_sentiment'],
#       dtype='object', length=156)

# %%
# These columns just represents the company's symbol and currency labels and is not useful so we drop it
nvda_data.drop(columns= ['symbol', 'CADUSD_label', 'KRWUSD_label', 'CNHUSD_label', 'GBPUSD_label', 'JPYUSD_label', 'EURUSD_label', 'CHFUSD_label', 'sector', 'exchange'], inplace=True)

# %%
# Function to obtain percentages of missing values 
def percent_missing(df):
    nan_percent = 100 * df.isnull().sum() / len(df)
    nan_percent = nan_percent[nan_percent > 0].sort_values(ascending=False)

    return nan_percent

# Function to plot out missing value percentages by column
def show_percent_missing(df):
    nan_percent = percent_missing(df)

    plt.figure(figsize=(24, 8))

    sns.barplot(x=nan_percent.index, y=nan_percent)
    plt.xticks(rotation=90)
    plt.ylabel('Missing Percentage %')
    plt.xlabel('Variables')

# %%
# Identifying values in this column that are not useful which we were generated by chat-GPT
nvda_data['NVDA_stock_news_sentiment'].unique()
# Out:
# array(['neutral', 'weakly_positive', 'strongly_positive',
#        'weakly_negative', 'strongly_negative',
#        "i'm sorry, but i cannot provide sentiment analysis for specific historical dates without direct access to news archives from that time.",
#        "i'm sorry, but i can’t provide that specific information."],
#       dtype=object)

# %%
# Replacing values that are not useful as missing 
nvda_data['NVDA_stock_news_sentiment'][nvda_data['NVDA_stock_news_sentiment'].str.contains("i'm sorry, but i", case=False, na=False)] = np.nan


# creating an exclusion to avoid replacing these as missing
exclusion = ['neutral', 'weakly_positive', 'weakly_negative', 'strongly_positive',  'strongly_negative']

# filling values as missing excluding those in the exclusion list
nvda_data['NVDA_press_release_sentiment'] = nvda_data['NVDA_press_release_sentiment'].apply(
    lambda x: x if x in exclusion else np.nan
)

print(nvda_data['NVDA_stock_news_sentiment'].unique())
print(nvda_data['NVDA_press_release_sentiment'].unique())
# Out:
# ['neutral' 'weakly_positive' 'strongly_positive' 'weakly_negative'
#  'strongly_negative' nan]
# ['neutral' 'strongly_positive' 'weakly_positive' 'weakly_negative'
#  'strongly_negative' nan]
# C:\Users\ekf98\AppData\Local\Temp\ipykernel_17832\4286128257.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nvda_data['NVDA_stock_news_sentiment'][nvda_data['NVDA_stock_news_sentiment'].str.contains("i'm sorry, but i", case=False, na=False)] = np.nan

# %%
# Creating a year and month column
nvda_data['month'] = nvda_data['date'].dt.month
nvda_data['year'] = nvda_data['date'].dt.year


# creating a function to classify the months based on the season
def season(month):
    if month in [12, 1, 2]:
        return 'Winter'
    elif month in [3,4,5]:
        return 'Spring'
    elif month in [6, 7, 8]:
        return 'Summer'
    else:
        return 'Fall'
    

# Creating a season column 
nvda_data['season'] = nvda_data['month'].apply(season)

nvda_data[['date', 'year', 'month', 'season']].sample(20)
# Out:
#            date  year  month  season
# 1494 2004-12-08  2004     12  Winter
# 4291 2015-12-03  2015     12  Winter
# 241  1999-12-31  1999     12  Winter
# 3524 2012-11-28  2012     11    Fall
# 3317 2012-02-03  2012      2  Winter
# 1092 2003-05-12  2003      5  Spring
# 3965 2014-08-22  2014      8  Summer
# 3188 2011-08-03  2011      8  Summer
# 5385 2020-03-26  2020      3  Spring
# 5052 2018-11-29  2018     11    Fall
# 5261 2019-09-30  2019      9    Fall
# 1857 2006-05-12  2006      5  Spring
# 1546 2005-02-22  2005      2  Winter
# 1424 2004-08-31  2004      8  Summer
# 2663 2009-07-14  2009      7  Summer
# 2863 2010-04-26  2010      4  Spring
# 2354 2008-04-25  2008      4  Spring
# 2180 2007-08-21  2007      8  Summer
# 5107 2019-02-21  2019      2  Winter
# 1429 2004-09-08  2004      9    Fall

# %%
# # Creating Subplots Grid

# fig, axes = plt.subplots(nrows=(len(nvda_data.columns) // 3) + 1, ncols=3, figsize=(15, 5 * ((len(nvda_data.columns) // 3) + 1)))

# # Flattening axes for easy iteration
# axes = axes.flatten()

# # plotting each numeric column against 'SalePrice'
# for i, col in enumerate(nvda_data.columns):
#     sns.scatterplot(x=nvda_data[col], y =nvda_data['NVDA_close'], ax=axes[i])
#     axes[i].set_title(f'{col} vs NVDA_close')

# # Hiding any extra subplots where numeric columns are not a multiple of 3
# for i in range(len(nvda_data.columns), len(axes)):
#     fig.delaxes(axes[i])

# plt.tight_layout()
# plt.show()

# %%
show_percent_missing(nvda_data)

# %%
percent_missing(nvda_data)
# Out:
# basicMaterialsChangesPercentage          100.000000000
# financialServicesChangesPercentage       100.000000000
# NVDA_twitter_social_sentiment             99.091322126
# CADUSD_change                             80.902620021
# CADUSD_traded_volume                      80.902620021
# CADUSD_adjClose                           80.902620021
# CADUSD_changePercent                      80.902620021
# CADUSD_vwap                               80.902620021
# CADUSD_changeOverTime                     80.902620021
# CADUSD_close                              80.902620021
# CADUSD_low                                80.902620021
# CADUSD_high                               80.902620021
# CADUSD_open                               80.902620021
# CADUSD_unadjusted_traded_Volume           80.902620021
# KRWUSD_low                                80.887475390
# KRWUSD_close                              80.887475390
# KRWUSD_adjClose                           80.887475390
# KRWUSD_traded_volume                      80.887475390
# KRWUSD_unadjusted_traded_Volume           80.887475390
# KRWUSD_change                             80.887475390
# KRWUSD_changePercent                      80.887475390
# JPYUSD_vwap                               80.887475390
# KRWUSD_changeOverTime                     80.887475390
# KRWUSD_high                               80.887475390
# KRWUSD_open                               80.887475390
# CNHUSD_changeOverTime                     80.887475390
# CNHUSD_vwap                               80.887475390
# CNHUSD_changePercent                      80.887475390
# CNHUSD_change                             80.887475390
# CNHUSD_unadjusted_traded_Volume           80.887475390
# CNHUSD_traded_volume                      80.887475390
# CNHUSD_adjClose                           80.887475390
# CNHUSD_close                              80.887475390
# CNHUSD_low                                80.887475390
# KRWUSD_vwap                               80.887475390
# EURUSD_open                               80.887475390
# JPYUSD_changePercent                      80.887475390
# CNHUSD_high                               80.887475390
# JPYUSD_change                             80.887475390
# JPYUSD_changeOverTime                     80.887475390
# JPYUSD_unadjusted_traded_Volume           80.887475390
# JPYUSD_traded_volume                      80.887475390
# JPYUSD_adjClose                           80.887475390
# JPYUSD_close                              80.887475390
# JPYUSD_low                                80.887475390
# JPYUSD_high                               80.887475390
# JPYUSD_open                               80.887475390
# GBPUSD_changeOverTime                     80.887475390
# GBPUSD_vwap                               80.887475390
# GBPUSD_changePercent                      80.887475390
# GBPUSD_change                             80.887475390
# GBPUSD_unadjusted_traded_Volume           80.887475390
# GBPUSD_traded_volume                      80.887475390
# GBPUSD_adjClose                           80.887475390
# GBPUSD_close                              80.887475390
# GBPUSD_low                                80.887475390
# GBPUSD_high                               80.887475390
# GBPUSD_open                               80.887475390
# EURUSD_changeOverTime                     80.887475390
# EURUSD_vwap                               80.887475390
# EURUSD_changePercent                      80.887475390
# EURUSD_change                             80.887475390
# EURUSD_unadjusted_traded_Volume           80.887475390
# EURUSD_traded_volume                      80.887475390
# EURUSD_adjClose                           80.887475390
# EURUSD_close                              80.887475390
# EURUSD_low                                80.887475390
# EURUSD_high                               80.887475390
# CNHUSD_open                               80.887475390
# CHFUSD_changeOverTime                     80.887475390
# CHFUSD_vwap                               80.887475390
# CHFUSD_changePercent                      80.887475390
# CHFUSD_change                             80.887475390
# CHFUSD_unadjusted_traded_Volume           80.887475390
# CHFUSD_traded_volume                      80.887475390
# CHFUSD_adjClose                           80.887475390
# CHFUSD_close                              80.887475390
# CHFUSD_low                                80.887475390
# CHFUSD_high                               80.887475390
# CHFUSD_open                               80.887475390
# month2                                    75.814023929
# Lithium_close                             44.025442980
# Lithium_open                              44.025442980
# Lithium_volume                            44.025442980
# Lithium_price                             44.025442980
# communicationServicesChangesPercentage    23.716492503
# consumerDefensiveChangesPercentage        23.716492503
# energyChangesPercentage                   23.716492503
# healthcareChangesPercentage               23.716492503
# industrialsChangesPercentage              23.716492503
# realEstateChangesPercentage               23.716492503
# technologyChangesPercentage               23.716492503
# utilitiesChangesPercentage                23.716492503
# consumerCyclicalChangesPercentage         23.716492503
# year30                                    15.856428896
# inflationRate                             15.704982584
# month1                                    10.343783129
# pe                                         3.665000757
# NVDA_press_release_sentiment               2.226260791
# month3                                     0.772376193
# year20                                     0.726942299
# year10                                     0.726942299
# year5                                      0.726942299
# year3                                      0.726942299
# year2                                      0.726942299
# year1                                      0.726942299
# month6                                     0.726942299
# year7                                      0.726942299
# Palladium_volume                           0.287747993
# Palladium_price                            0.287747993
# Palladium_open                             0.287747993
# Palladium_close                            0.287747993
# Copper_close                               0.257458731
# Copper_price                               0.257458731
# Copper_open                                0.257458731
# Copper_volume                              0.257458731
# Gold_open                                  0.166590944
# Silver_volume                              0.166590944
# Gold_close                                 0.166590944
# Silver_price                               0.166590944
# Gold_volume                                0.166590944
# Gold_price                                 0.166590944
# Silver_close                               0.166590944
# Silver_open                                0.166590944
# sma                                        0.060578525
# adx                                        0.060578525
# ema                                        0.060578525
# rsi                                        0.060578525
# standardDeviation                          0.060578525
# tema                                       0.060578525
# williams                                   0.060578525
# wma                                        0.060578525
# dema                                       0.060578525
# NVDA_stock_news_sentiment                  0.030289262
# dtype: float64

# %%
nan_percent = 100 * nvda_data.isnull().sum() / len(nvda_data)
nan_percent = nan_percent[nan_percent > 0].sort_values(ascending=False)

cols_to_drop = nan_percent[nan_percent >= 75].index

nvda_data.drop(columns=cols_to_drop, inplace=True)

# %%
show_percent_missing(nvda_data)

# %%
percent_missing(nvda_data)
# Out:
# Lithium_price                            44.025442980
# Lithium_close                            44.025442980
# Lithium_open                             44.025442980
# Lithium_volume                           44.025442980
# technologyChangesPercentage              23.716492503
# consumerCyclicalChangesPercentage        23.716492503
# consumerDefensiveChangesPercentage       23.716492503
# energyChangesPercentage                  23.716492503
# healthcareChangesPercentage              23.716492503
# industrialsChangesPercentage             23.716492503
# realEstateChangesPercentage              23.716492503
# utilitiesChangesPercentage               23.716492503
# communicationServicesChangesPercentage   23.716492503
# year30                                   15.856428896
# inflationRate                            15.704982584
# month1                                   10.343783129
# pe                                        3.665000757
# NVDA_press_release_sentiment              2.226260791
# month3                                    0.772376193
# year10                                    0.726942299
# year1                                     0.726942299
# year7                                     0.726942299
# year5                                     0.726942299
# year3                                     0.726942299
# year20                                    0.726942299
# month6                                    0.726942299
# year2                                     0.726942299
# Palladium_price                           0.287747993
# Palladium_volume                          0.287747993
# Palladium_open                            0.287747993
# Palladium_close                           0.287747993
# Copper_price                              0.257458731
# Copper_close                              0.257458731
# Copper_open                               0.257458731
# Copper_volume                             0.257458731
# Gold_volume                               0.166590944
# Gold_close                                0.166590944
# Gold_open                                 0.166590944
# Silver_volume                             0.166590944
# Gold_price                                0.166590944
# Silver_close                              0.166590944
# Silver_open                               0.166590944
# Silver_price                              0.166590944
# adx                                       0.060578525
# dema                                      0.060578525
# ema                                       0.060578525
# rsi                                       0.060578525
# standardDeviation                         0.060578525
# tema                                      0.060578525
# williams                                  0.060578525
# wma                                       0.060578525
# sma                                       0.060578525
# NVDA_stock_news_sentiment                 0.030289262
# dtype: float64

# %%
nvda_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6603 entries, 0 to 6639
# Data columns (total 68 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   date                                    6603 non-null   datetime64[ns]
#  1   NVDA_close                              6603 non-null   float64
#  2   NVDA_high                               6603 non-null   float64
#  3   NVDA_low                                6603 non-null   float64
#  4   NVDA_open                               6603 non-null   float64
#  5   NVDA_traded_volume                      6603 non-null   int64
#  6   NVDA_adjClose                           6603 non-null   float64
#  7   NVDA_adjLow                             6603 non-null   float64
#  8   NVDA_adjOpen                            6603 non-null   float64
#  9   NVDA_adj_traded_volume                  6603 non-null   int64
#  10  NVDA_divCash                            6603 non-null   float64
#  11  NVDA_splitFactor                        6603 non-null   float64
#  12  pe                                      6361 non-null   float64
#  13  communicationServicesChangesPercentage  5037 non-null   float64
#  14  consumerCyclicalChangesPercentage       5037 non-null   float64
#  15  consumerDefensiveChangesPercentage      5037 non-null   float64
#  16  energyChangesPercentage                 5037 non-null   float64
#  17  healthcareChangesPercentage             5037 non-null   float64
#  18  industrialsChangesPercentage            5037 non-null   float64
#  19  realEstateChangesPercentage             5037 non-null   float64
#  20  technologyChangesPercentage             5037 non-null   float64
#  21  utilitiesChangesPercentage              5037 non-null   float64
#  22  month1                                  5920 non-null   float64
#  23  month3                                  6552 non-null   float64
#  24  month6                                  6555 non-null   float64
#  25  year1                                   6555 non-null   float64
#  26  year2                                   6555 non-null   float64
#  27  year3                                   6555 non-null   float64
#  28  year5                                   6555 non-null   float64
#  29  year7                                   6555 non-null   float64
#  30  year10                                  6555 non-null   float64
#  31  year20                                  6555 non-null   float64
#  32  year30                                  5556 non-null   float64
#  33  inflationRate                           5566 non-null   float64
#  34  Palladium_price                         6584 non-null   float64
#  35  Palladium_volume                        6584 non-null   float64
#  36  Palladium_open                          6584 non-null   float64
#  37  Palladium_close                         6584 non-null   float64
#  38  Copper_price                            6586 non-null   float64
#  39  Copper_volume                           6586 non-null   float64
#  40  Copper_open                             6586 non-null   float64
#  41  Copper_close                            6586 non-null   float64
#  42  Lithium_price                           3696 non-null   float64
#  43  Lithium_volume                          3696 non-null   float64
#  44  Lithium_open                            3696 non-null   float64
#  45  Lithium_close                           3696 non-null   float64
#  46  Silver_price                            6592 non-null   float64
#  47  Silver_volume                           6592 non-null   float64
#  48  Silver_open                             6592 non-null   float64
#  49  Silver_close                            6592 non-null   float64
#  50  Gold_price                              6592 non-null   float64
#  51  Gold_volume                             6592 non-null   float64
#  52  Gold_open                               6592 non-null   float64
#  53  Gold_close                              6592 non-null   float64
#  54  sma                                     6599 non-null   float64
#  55  adx                                     6599 non-null   float64
#  56  dema                                    6599 non-null   float64
#  57  ema                                     6599 non-null   float64
#  58  rsi                                     6599 non-null   float64
#  59  standardDeviation                       6599 non-null   float64
#  60  tema                                    6599 non-null   float64
#  61  williams                                6599 non-null   float64
#  62  wma                                     6599 non-null   float64
#  63  NVDA_stock_news_sentiment               6601 non-null   object
#  64  NVDA_press_release_sentiment            6456 non-null   object
#  65  month                                   6603 non-null   int32
#  66  year                                    6603 non-null   int32
#  67  season                                  6603 non-null   object
# dtypes: datetime64[ns](1), float64(60), int32(2), int64(2), object(3)
# memory usage: 3.4+ MB

# %%
# Filling missing values of NVDA_stock_news_sentiment with mode by each year and month
nvda_data['NVDA_stock_news_sentiment']  = nvda_data.groupby(['year', 'month'])['NVDA_stock_news_sentiment'].transform(lambda value: value.fillna(value.mode().iloc[0]))

# Filling missing values of NVDA_press_release_sentiment with mode by each year and month
nvda_data['NVDA_press_release_sentiment']  = nvda_data.groupby(['year', 'month'])['NVDA_press_release_sentiment'].transform(lambda value: value.fillna(value.mode().iloc[0]))


# Grouping by year and month or just the year and then filling with the mode or median
def fill_values(feature, dataset):

    dataset[feature] = dataset.groupby(['year', 'month'])[feature].transform(lambda value: value.fillna(value.median()))

    if dataset[feature].isnull().any():
        dataset[feature] = dataset.groupby('year')[feature].transform(lambda value: value.fillna(value.median()))
        

cols_to_fill = ['Gold_volume', 'Gold_close', 'Gold_open', 'Gold_price', 'Copper_close','Copper_price',
                'Copper_volume', 'Copper_open', 'Palladium_price', 'Palladium_volume', 'Palladium_open',
                'Palladium_close', 'Silver_close', 'Silver_open', 'Silver_volume', 'Silver_price',
                'Lithium_volume', 'Lithium_close', 'Lithium_open', 'Lithium_price', 'sma', 'adx', 'dema',
                'ema', 'rsi', 'standardDeviation', 'tema', 'williams', 'wma', 'month3', 'year3', 'year5',
                'year7', 'year10', 'year20', 'year2', 'year1', 'month6', 'realEstateChangesPercentage',
                'utilitiesChangesPercentage', 'communicationServicesChangesPercentage', 'technologyChangesPercentage',
                'industrialsChangesPercentage', 'healthcareChangesPercentage', 'energyChangesPercentage',  
                'consumerDefensiveChangesPercentage', 'consumerCyclicalChangesPercentage', 'year30',
                'inflationRate', 'month1', 'pe']

# Filling columns as defined in function
for col in cols_to_fill:
    fill_values(col, nvda_data)


# Filling inflation rate and interest rates with their respective medians
nvda_data['inflationRate'] = nvda_data['inflationRate'].fillna(nvda_data['inflationRate'].median())
nvda_data['year30'] = nvda_data['year30'].fillna(nvda_data['year30'].median())
nvda_data['month1'] = nvda_data['month1'].fillna(nvda_data['month1'].median())

# %%
# cols_to_map = ['AAPL_stock_news_sentiment', 'NVDA_stock_news_sentiment', 'AAPL_press_release_sentiment', 'NVDA_press_release_sentiment'] 


# category_mapping = {'neutral': 0, 'weakly_positive': 0.5, 'strongly_positive': 1, 'weakly_negative': -0.5, 'strongly_negative': 1}

# # mapping using lambda function
# aapl_data[cols_to_map] = aapl_data[cols_to_map].apply(lambda col: col.map(category_mapping))

# %%
percent_missing(nvda_data)
# Out:
# Lithium_price    41.905194609
# Lithium_volume   41.905194609
# Lithium_open     41.905194609
# Lithium_close    41.905194609
# dtype: float64

# %%
# Select only numerical columns
numeric_data = nvda_data.select_dtypes(include=['float64', 'int32', 'int64'])

# Compute correlation of 'Lithium_price' with all other numeric columns
lithium_corr = numeric_data.corr()['Lithium_price'].dropna()

# Compute correlation of 'Lithium_close' with all other numeric columns
lithium_close = numeric_data.corr()['Lithium_close'].dropna()

# Compute correlation of 'Lithium_open' with all other numeric columns
lithium_open = numeric_data.corr()['Lithium_open'].dropna()

# Compute correlation of 'Lithium_open' with all other numeric columns
lithium_vol = numeric_data.corr()['Lithium_volume'].dropna()

# Filter only correlations with absolute value > 0.70
strong_corr = lithium_corr[abs(lithium_corr) > 0.70]

strong_corr_close = lithium_close[abs(lithium_close) > 0.70]

strong_corr_open = lithium_open[abs(lithium_open) > 0.70]

strong_corr_vol = lithium_vol[abs(lithium_vol) > 0.50]


# Print correlation values sorted in descending order
print(strong_corr.sort_values(ascending=False, key=abs), strong_corr_close.sort_values(ascending=False, key=abs), 
      strong_corr_open.sort_values(ascending=False, key=abs), strong_corr_vol.sort_values(ascending=False, key=abs))
# Out:
# Lithium_price   1.000000000
# Lithium_close   1.000000000
# Lithium_open    0.999540518
# Copper_price    0.708571244
# Copper_close    0.708571244
# Copper_open     0.707160101
# Name: Lithium_price, dtype: float64 Lithium_price   1.000000000
# Lithium_close   1.000000000
# Lithium_open    0.999540518
# Copper_price    0.708571244
# Copper_close    0.708571244
# Copper_open     0.707160101
# Name: Lithium_close, dtype: float64 Lithium_open    1.000000000
# Lithium_price   0.999540518
# Lithium_close   0.999540518
# Copper_price    0.708361199
# Copper_close    0.708361199
# Copper_open     0.707412306
# Name: Lithium_open, dtype: float64 Lithium_volume    1.000000000
# Lithium_open      0.697392606
# Lithium_price     0.697043543
# Lithium_close     0.697043543
# Palladium_open    0.632903291
# Palladium_price   0.631794348
# Palladium_close   0.631794348
# year              0.568145316
# NVDA_high         0.548338843
# NVDA_open         0.547652433
# NVDA_close        0.546892928
# NVDA_low          0.545964769
# Silver_volume     0.520894775
# Name: Lithium_volume, dtype: float64

# %%
# Create figure and axes for two subplots side by side
fig, axes = plt.subplots(1, 8, figsize=(24, 6), sharex=True)

# Flatten the axes array for easy indexing
axes = axes.flatten()

# First scatter plot: Gold price
sns.scatterplot(x=nvda_data['date'], y=nvda_data['Copper_price'], ax=axes[0], color='gold')
axes[0].set_title('Copper Current Price Over Time')
axes[0].set_ylabel('Copper Current Price')

# Second scatter plot: Lithium price
sns.scatterplot(x=nvda_data['date'], y=nvda_data['Lithium_price'], ax=axes[1], color='yellow')
axes[1].set_title('Lithium Current Price Over Time')
axes[1].set_ylabel('Lithium Current Price')

# third scatter plot: Copper_close
sns.scatterplot(x=nvda_data['date'], y=nvda_data['Copper_close'], ax=axes[2], color='red')
axes[2].set_title('Copper Close Price Over Time')
axes[2].set_ylabel('Copper Close Price')

# fourth scatter plot: Lithium close
sns.scatterplot(x=nvda_data['date'], y=nvda_data['Lithium_close'], ax=axes[3], color='pink')
axes[3].set_title('Lithium Close Price Over Time')
axes[3].set_ylabel('Lithium Close Price')

# fifth scatter plot: Copper_open
sns.scatterplot(x=nvda_data['date'], y=nvda_data['Copper_open'], ax=axes[4], color='blue')
axes[4].set_title('Copper Open Price Over Time')
axes[4].set_ylabel('Copper Open Price')

# Sixth scatter plot: Lithium open
sns.scatterplot(x=nvda_data['date'], y=nvda_data['Lithium_open'], ax=axes[5], color='green')
axes[5].set_title('Lithium Open Price Over Time')
axes[5].set_ylabel('Lithium Open Price')

# Seventh scatter plot: Copper_open
sns.scatterplot(x=nvda_data['date'], y=nvda_data['Silver_volume'], ax=axes[6], color='black')
axes[6].set_title('Silver Volume Price Over Time')
axes[6].set_ylabel('Silver Volume Price')

# Eighth scatter plot: Lithium open
sns.scatterplot(x=nvda_data['date'], y=nvda_data['Lithium_volume'], ax=axes[7], color='brown')
axes[7].set_title('Lithium Volume Price Over Time')
axes[7].set_ylabel('Lithium Volume Price')

# Rotate x-axis labels for better readability
for ax in axes:
    ax.set_xlabel('Date')
    ax.tick_params(axis='x', rotation=45)

plt.tight_layout()  
plt.show()

# %%
def linear_reg_filling(col_to_fill, col_to_use, dataset):
    """ 
    col_to_fill: This is essentially the column to fill missing values on 
    col_to_use: This is the column that is trained on the linear model to create predictions on col_to_fill
    dataset: The dataset to use 
    """

    # The correlation between copper and lithium features are high (0.70). Hence, I would use a linear regression model to predict the missing values of lithium and fill them up
    # A similar correlation is shown for the other features plotted above
    from sklearn.linear_model import LinearRegression


    # Add a small constant to avoid issues with log(0)
    epsilon = 1e-5

    dataset[f"{col}_log"] = np.log(dataset[col_to_fill] + epsilon)

    # Extract rows with missing column values
    missing_data = dataset[dataset[col_to_fill].isna()]

    # Use non-missing values for fitting the regression model
    train_data = dataset.dropna(subset=[col_to_fill])

    # Reshape data to 2D (needed for sklearn)
    X_train = train_data[[col_to_use]]  # Copper as independent variable
    y_train = train_data[f"{col}_log"]  # Lithium as dependent variable

    
    # Fit linear regression model
    model = LinearRegression()
    model.fit(X_train, y_train)

    # Predict Lithium values for the missing data
    X_missing = missing_data[[col_to_use]]
    predicted_col_log = model.predict(X_missing)

    # Apply inverse log transformation to predict original Lithium values
    predictions = np.exp(predicted_col_log) - epsilon

    # Fill missing Lithium values with the predicted values
    dataset.loc[dataset[col_to_fill].isna(), col_to_fill] = predictions


linear_reg_filling('Lithium_price', 'Copper_price', nvda_data)
linear_reg_filling('Lithium_close', 'Copper_close', nvda_data)
linear_reg_filling('Lithium_open', 'Copper_open', nvda_data)
linear_reg_filling('Lithium_volume', 'Silver_volume', nvda_data)

# %%
# Create figure and axes for two subplots side by side
fig, axes = plt.subplots(1, 8, figsize=(24, 6), sharex=True)

# Flatten the axes array for easy indexing
axes = axes.flatten()

# First scatter plot: Gold price
sns.scatterplot(x=nvda_data['date'], y=nvda_data['Copper_price'], ax=axes[0], color='gold')
axes[0].set_title('Copper Current Price Over Time')
axes[0].set_ylabel('Copper Current Price')

# Second scatter plot: Lithium price
sns.scatterplot(x=nvda_data['date'], y=nvda_data['Lithium_price'], ax=axes[1], color='yellow')
axes[1].set_title('Lithium Current Price Over Time')
axes[1].set_ylabel('Lithium Current Price')

# third scatter plot: Copper_close
sns.scatterplot(x=nvda_data['date'], y=nvda_data['Copper_close'], ax=axes[2], color='red')
axes[2].set_title('Copper Close Price Over Time')
axes[2].set_ylabel('Copper Close Price')

# fourth scatter plot: Lithium close
sns.scatterplot(x=nvda_data['date'], y=nvda_data['Lithium_close'], ax=axes[3], color='pink')
axes[3].set_title('Lithium Close Price Over Time')
axes[3].set_ylabel('Lithium Close Price')

# fifth scatter plot: Copper_open
sns.scatterplot(x=nvda_data['date'], y=nvda_data['Copper_open'], ax=axes[4], color='blue')
axes[4].set_title('Copper Open Price Over Time')
axes[4].set_ylabel('Copper Open Price')

# Sixth scatter plot: Lithium open
sns.scatterplot(x=nvda_data['date'], y=nvda_data['Lithium_open'], ax=axes[5], color='green')
axes[5].set_title('Lithium Open Price Over Time')
axes[5].set_ylabel('Lithium Open Price')

# Seventh scatter plot: Copper_open
sns.scatterplot(x=nvda_data['date'], y=nvda_data['Silver_volume'], ax=axes[6], color='black')
axes[6].set_title('Silver Volume Price Over Time')
axes[6].set_ylabel('Silver Volume Price')

# Eighth scatter plot: Lithium open
sns.scatterplot(x=nvda_data['date'], y=nvda_data['Lithium_volume'], ax=axes[7], color='brown')
axes[7].set_title('Lithium Volume Price Over Time')
axes[7].set_ylabel('Lithium Volume Price')

# Rotate x-axis labels for better readability
for ax in axes:
    ax.set_xlabel('Date')
    ax.tick_params(axis='x', rotation=45)

plt.tight_layout()  
plt.show()

# %%
nvda_data.drop(columns='pe_log', inplace=True)

percent_missing(nvda_data)
# Out:
# Series([], dtype: float64)

# %%
nvda_data.isnull().sum()
# Out:
# date                                      0
# NVDA_close                                0
# NVDA_high                                 0
# NVDA_low                                  0
# NVDA_open                                 0
# NVDA_traded_volume                        0
# NVDA_adjClose                             0
# NVDA_adjLow                               0
# NVDA_adjOpen                              0
# NVDA_adj_traded_volume                    0
# NVDA_divCash                              0
# NVDA_splitFactor                          0
# pe                                        0
# communicationServicesChangesPercentage    0
# consumerCyclicalChangesPercentage         0
# consumerDefensiveChangesPercentage        0
# energyChangesPercentage                   0
# healthcareChangesPercentage               0
# industrialsChangesPercentage              0
# realEstateChangesPercentage               0
# technologyChangesPercentage               0
# utilitiesChangesPercentage                0
# month1                                    0
# month3                                    0
# month6                                    0
# year1                                     0
# year2                                     0
# year3                                     0
# year5                                     0
# year7                                     0
# year10                                    0
# year20                                    0
# year30                                    0
# inflationRate                             0
# Palladium_price                           0
# Palladium_volume                          0
# Palladium_open                            0
# Palladium_close                           0
# Copper_price                              0
# Copper_volume                             0
# Copper_open                               0
# Copper_close                              0
# Lithium_price                             0
# Lithium_volume                            0
# Lithium_open                              0
# Lithium_close                             0
# Silver_price                              0
# Silver_volume                             0
# Silver_open                               0
# Silver_close                              0
# Gold_price                                0
# Gold_volume                               0
# Gold_open                                 0
# Gold_close                                0
# sma                                       0
# adx                                       0
# dema                                      0
# ema                                       0
# rsi                                       0
# standardDeviation                         0
# tema                                      0
# williams                                  0
# wma                                       0
# NVDA_stock_news_sentiment                 0
# NVDA_press_release_sentiment              0
# month                                     0
# year                                      0
# season                                    0
# dtype: int64

# %%
# creating a separate copy for other models that do not require creating lagged features
separate_nvda_data = nvda_data.copy()

# %%
nvda_data.sample(8).sort_values('date')
# Out:
#            date    NVDA_close     NVDA_high      NVDA_low     NVDA_open  \
# 846  2002-05-23  35.730000000  38.240000000  34.600000000  38.160000000
# 1725 2005-11-03  34.650000000  35.500000000  34.370000000  35.300000000
# 1945 2006-09-14  28.990000000  29.500000000  28.610000000  28.960000000
# 2164 2007-07-30  45.490000000  45.560000000  44.400000000  44.410000000
# 2268 2007-12-21  35.160000000  35.900000000  34.840000000  35.590000000
# 3610 2013-04-03  12.126000000  12.330000000  12.040000000  12.260000000
# 3634 2013-05-07  13.650000000  13.860000000  13.520000000  13.830000000
# 4875 2018-03-22 241.850000000 247.880000000 240.340000000 246.000000000
#
#       NVDA_traded_volume  NVDA_adjClose  NVDA_adjLow  NVDA_adjOpen  \
# 846             21306500    0.273091339  0.264454529   0.291664301
# 1725             3875600    0.264836688  0.262696594   0.269804765
# 1945             7146867    0.443152416  0.437343588   0.442693824
# 2164             8969267    0.695377833  0.678715669   0.678868533
# 2268            10835200    0.806203750  0.798866287   0.816063466
# 3610             8828900    0.281555698  0.279558849   0.284667067
# 3634            11201700    0.316941719  0.313923226   0.321121170
# 4875            13663927    5.984422151  5.947058176   6.087111222
#
#       NVDA_adj_traded_volume  NVDA_divCash  NVDA_splitFactor            pe  \
# 846               2556778721   0.000000000       1.000000000 400.571322900
# 1725               465071767   0.000000000       1.000000000   4.394825316
# 1945               428811805   0.000000000       1.000000000   9.071012563
# 2164               538155750   0.000000000       1.000000000  10.417816370
# 2268               433408000   0.000000000       1.000000000  14.496242370
# 3610               353156000   0.000000000       1.000000000   5.119502711
# 3634               448068000   0.000000000       1.000000000   4.664905906
# 4875               546557080   0.000000000       1.000000000  25.051599690
#
#       communicationServicesChangesPercentage  \
# 846                              1.946220000
# 1725                             0.129170000
# 1945                             0.002300000
# 2164                             0.930400000
# 2268                            -0.237730000
# 3610                            -1.133770000
# 3634                             0.538895000
# 4875                            -3.389400000
#
#       consumerCyclicalChangesPercentage  consumerDefensiveChangesPercentage  \
# 846                         1.509750000                        -0.056420000
# 1725                       -0.811370000                        -0.052830000
# 1945                        1.283915000                        -0.370040000
# 2164                        0.086810000                         0.467160000
# 2268                       -0.051200000                        -0.450600000
# 3610                       -0.769230000                        -1.189740000
# 3634                       -0.003235000                        -0.482110000
# 4875                       -4.068800000                        -1.417970000
#
#       energyChangesPercentage  healthcareChangesPercentage  \
# 846               1.280050000                 -6.976020000
# 1725              1.595690000                  5.732530000
# 1945             -0.259695000                 -0.830965000
# 2164              1.021720000                 -1.483190000
# 2268             -0.233255000                 -0.034200000
# 3610             -2.213160000                 -1.390560000
# 3634              0.290765000                  1.269325000
# 4875             -2.170560000                  0.490890000
#
#       industrialsChangesPercentage  realEstateChangesPercentage  \
# 846                    1.221180000                  1.793260000
# 1725                   2.470050000                 -0.383060000
# 1945                  -0.838350000                 -0.342260000
# 2164                  -2.083270000                  0.938890000
# 2268                  -3.095185000                 -1.367475000
# 3610                  -2.290580000                 -0.599830000
# 3634                  -1.889710000                 -0.576060000
# 4875                  -2.788210000                 -0.420220000
#
#       technologyChangesPercentage  utilitiesChangesPercentage      month1  \
# 846                   1.065570000                 1.231960000 1.730000000
# 1725                  0.000120000                 0.091450000 3.810000000
# 1945                 -0.000085000                -0.363295000 4.810000000
# 2164                  0.027190000                 0.582070000 4.950000000
# 2268                 -0.093205000                 0.122420000 2.440000000
# 3610                 -2.514420000                -0.340940000 0.060000000
# 3634                  0.551685000                -0.959555000 0.010000000
# 4875                 -2.417750000                 0.459660000 1.670000000
#
#           month3      month6       year1       year2       year3       year5  \
# 846  1.740000000 1.910000000 2.380000000 3.280000000 3.800000000 4.460000000
# 1725 3.940000000 4.270000000 4.330000000 4.470000000 4.500000000 4.550000000
# 1945 4.950000000 5.120000000 5.020000000 4.830000000 4.770000000 4.740000000
# 2164 4.960000000 5.000000000 4.870000000 4.590000000 4.570000000 4.640000000
# 2268 3.000000000 3.380000000 3.310000000 3.190000000 3.200000000 3.580000000
# 3610 0.060000000 0.100000000 0.130000000 0.240000000 0.340000000 0.730000000
# 3634 0.040000000 0.080000000 0.100000000 0.220000000 0.350000000 0.750000000
# 4875 1.720000000 1.950000000 2.050000000 2.290000000 2.430000000 2.630000000
#
#            year7      year10      year20      year30  inflationRate  \
# 846  4.870000000 5.160000000 5.830000000 5.400000000    2.190000000
# 1725 4.590000000 4.650000000 4.940000000 3.730000000    2.620000000
# 1945 4.750000000 4.790000000 4.990000000 4.920000000    2.440000000
# 2164 4.710000000 4.820000000 5.050000000 4.970000000    2.330000000
# 2268 3.840000000 4.180000000 4.620000000 4.580000000    2.340000000
# 3610 1.200000000 1.830000000 2.660000000 3.050000000    2.480000000
# 3634 1.210000000 1.820000000 2.620000000 3.000000000    2.320000000
# 4875 2.760000000 2.830000000 2.940000000 3.060000000    2.080000000
#
#       Palladium_price  Palladium_volume  Palladium_open  Palladium_close  \
# 846     354.000000000     226.000000000   360.000000000    354.000000000
# 1725    231.900000000     610.000000000   227.300000000    231.900000000
# 1945    327.200000000     672.000000000   319.000000000    327.200000000
# 2164    367.300000000    1232.000000000   363.700000000    367.300000000
# 2268    361.150000000     420.000000000   357.500000000    361.150000000
# 3610    755.450000000    4988.000000000   766.050000000    755.450000000
# 3634    680.600000000    4390.000000000   696.000000000    680.600000000
# 4875    981.800000000    4392.000000000   984.500000000    981.800000000
#
#       Copper_price    Copper_volume  Copper_open  Copper_close  Lithium_price  \
# 846    0.736000000   8827.000000000  0.728500000   0.736000000   11.575484019
# 1725   1.827000000  11801.000000000  1.826500000   1.827000000   18.539537087
# 1945   3.374500000   5981.000000000  3.385000000   3.374500000   36.161889611
# 2164   3.588500000   7456.000000000  3.529500000   3.588500000   39.662086286
# 2268   3.097500000   9145.000000000  2.967500000   3.097500000   32.085908513
# 3610   3.333000000  59532.000000000  3.373000000   3.333000000   26.240000000
# 3634   3.302500000  79218.000000000  3.297000000   3.302500000   25.440000000
# 4875   3.020000000 125081.000000000  3.078500000   3.020000000   33.900000000
#
#        Lithium_volume  Lithium_open  Lithium_close  Silver_price  \
# 846   29891.782535737  11.566209041   11.575484019   4.820000000
# 1725  29891.782535737  18.566115561   18.539537087   7.575000000
# 1945  29891.782535737  36.345448912   36.161889611  10.695000000
# 2164  29891.782535737  38.681060684   39.662086286  12.885000000
# 2268  29891.782535737  30.359876088   32.085908513  14.368700000
# 3610  20350.000000000  26.600000000   26.240000000  26.981000000
# 3634  10600.000000000  25.280000000   25.440000000  23.937000000
# 4875 257959.000000000  34.470000000   33.900000000  16.366000000
#
#        Silver_volume  Silver_open  Silver_close     Gold_price  \
# 846      0.000000000  4.825000000   4.820000000  322.050000000
# 1725     0.000000000  7.535000000   7.575000000  461.100000000
# 1945     0.000000000 11.185000000  10.695000000  575.250000000
# 2164     0.000000000 12.655000000  12.885000000  665.000000000
# 2268     0.000000000 14.215000000  14.368700000  811.720000000
# 3610 36052.000000000 27.259000000  26.981000000 1557.700000000
# 3634 50698.000000000 23.982000000  23.937000000 1452.410000000
# 4875 98043.000000000 16.548000000  16.366000000 1328.790000000
#
#           Gold_volume      Gold_open     Gold_close         sma           adx  \
# 846       0.000000000  317.950000000  322.050000000 0.297750000 100.000000000
# 1725      0.000000000  463.150000000  461.100000000 0.288750000 100.000000000
# 1945      0.000000000  589.850000000  575.250000000 0.483170000 100.000000000
# 2164      0.000000000  661.100000000  665.000000000 0.758170000   0.000000000
# 2268      0.000000000  796.200000000  811.720000000 0.879000000 100.000000000
# 3610  77988.000000000 1575.790000000 1557.700000000 0.303150000 100.000000000
# 3634  87179.000000000 1469.200000000 1452.410000000 0.341250000 100.000000000
# 4875 407527.000000000 1332.050000000 1328.790000000 6.050000000 100.000000000
#
#             dema         ema           rsi  standardDeviation        tema  \
# 846  0.297750000 0.297750000   0.000000000        0.000000000 0.297750000
# 1725 0.288750000 0.288750000   0.000000000        0.000000000 0.288750000
# 1945 0.483170000 0.483170000   0.000000000        0.000000000 0.483170000
# 2164 0.758170000 0.758170000 100.000000000        0.000000000 0.758170000
# 2268 0.879000000 0.879000000   0.000000000        0.000000000 0.879000000
# 3610 0.303150000 0.303150000   0.000000000        0.000000000 0.303150000
# 3634 0.341250000 0.341250000   0.000000000        0.000000000 0.341250000
# 4875 6.050000000 6.050000000   0.000000000        0.000000000 6.050000000
#
#           williams         wma NVDA_stock_news_sentiment  \
# 846  -68.951878708 0.297750000                   neutral
# 1725 -75.239107333 0.288750000                   neutral
# 1945 -57.316250843 0.483170000                   neutral
# 2164  -6.049638056 0.758170000                   neutral
# 2268 -69.811320755 0.879000000                   neutral
# 3610 -70.344827586 0.303150000                   neutral
# 3634 -61.764705882 0.341250000                   neutral
# 4875 -78.947368421 6.050000000           weakly_negative
#
#      NVDA_press_release_sentiment  month  year  season
# 846                       neutral      5  2002  Spring
# 1725                      neutral     11  2005    Fall
# 1945                      neutral      9  2006    Fall
# 2164              weakly_negative      7  2007  Summer
# 2268              weakly_negative     12  2007  Winter
# 3610                      neutral      4  2013  Spring
# 3634                      neutral      5  2013  Spring
# 4875                      neutral      3  2018  Spring

# %%
def created_lagged_features_daily(data, target_col, external_features, max_lag=10):
    df = data.copy()

    # lag target feature (stock price) from 1 to 7 days
    # for lag in range(1, 8):
    for lag in range(1, max_lag + 1):
        df[f'{target_col}_lag_{lag}'] = df[target_col].shift(lag)

    # Selectively lagging external features with specific lags
    for feature in external_features:
        if feature == 'inflationRate':
            # attempting to capture long-term dependency with max lags
            for lag in range(1, max_lag + 1):
                df[f'{feature}_lag_{lag}'] = df[feature].shift(lag)

        elif feature == 'Gold_price':
            # lagging short-term dependencies
            # for lag in range(1, 8):
            for lag in range(1, max_lag + 1):
                df[f'{feature}_lag_{lag}'] = df[feature].shift(lag)
        
        elif feature == 'Silver_price':
            # lagging short-term dependencies
            # for lag in range(1, 8):
            for lag in range(1, max_lag + 1):
                df[f'{feature}_lag_{lag}'] = df[feature].shift(lag)

        elif feature == 'NVDA_press_release_sentiment':
            # lagging very short-term dependencies for news sentiments as news trends change often
            # for lag in range(1, 6):
            for lag in range(1, max_lag + 1):
                df[f'{feature}_lag_{lag}'] = df[feature].shift(lag)

        elif feature == 'NVDA_stock_news_sentiment':
            # lagging short-term dependencies for press releases
            # for lag in range(1, 8):
            for lag in range(1, max_lag + 1):
                df[f'{feature}_lag_{lag}'] = df[feature].shift(lag)
    
    df.dropna(inplace=True) # dropping all NaN values after shifting
    
    return df

# %%
external_features = ['Silver_price', 'inflationRate', 'NVDA_stock_news_sentiment', 'Gold_price', 'NVDA_press_release_sentiment']

nvda_data = created_lagged_features_daily(nvda_data, 'NVDA_close', external_features=external_features)

nvda_data['day'] = nvda_data['date'].dt.day

nvda_data.head()
# Out:
#          date   NVDA_close    NVDA_high     NVDA_low    NVDA_open  \
# 10 1999-02-05 19.810000000 20.000000000 19.060000000 19.560000000
# 11 1999-02-08 19.130000000 20.000000000 19.130000000 19.940000000
# 12 1999-02-09 18.380000000 19.630000000 18.130000000 19.500000000
# 13 1999-02-10 18.190000000 18.880000000 17.880000000 18.380000000
# 14 1999-02-11 19.750000000 20.500000000 18.250000000 18.250000000
#
#     NVDA_traded_volume  NVDA_adjClose  NVDA_adjLow  NVDA_adjOpen  \
# 10              285100    0.037852921  0.036419822   0.037375221
# 11              321000    0.036553578  0.036553578   0.038101324
# 12              181200    0.035120479  0.034642779   0.037260573
# 13              308800    0.034757427  0.034165079   0.035120479
# 14              275500    0.037738273  0.034872075   0.034872075
#
#     NVDA_adj_traded_volume  NVDA_divCash  NVDA_splitFactor           pe  \
# 10               136847931   0.000000000       1.000000000 82.589342710
# 11               154079922   0.000000000       1.000000000 82.589342710
# 12                86975956   0.000000000       1.000000000 82.589342710
# 13               148223925   0.000000000       1.000000000 82.589342710
# 14               132239933   0.000000000       1.000000000 82.589342710
#
#     communicationServicesChangesPercentage  consumerCyclicalChangesPercentage  \
# 10                             0.853720000                       -0.307020000
# 11                             0.853720000                       -0.307020000
# 12                             0.853720000                       -0.307020000
# 13                             0.853720000                       -0.307020000
# 14                             0.853720000                       -0.307020000
#
#     consumerDefensiveChangesPercentage  energyChangesPercentage  \
# 10                        -0.737890000             -0.311530000
# 11                        -0.737890000             -0.311530000
# 12                        -0.737890000             -0.311530000
# 13                        -0.737890000             -0.311530000
# 14                        -0.737890000             -0.311530000
#
#     healthcareChangesPercentage  industrialsChangesPercentage  \
# 10                  0.781540000                   0.297280000
# 11                  0.781540000                   0.297280000
# 12                  0.781540000                   0.297280000
# 13                  0.781540000                   0.297280000
# 14                  0.781540000                   0.297280000
#
#     realEstateChangesPercentage  technologyChangesPercentage  \
# 10                  0.386630000                 -0.000910000
# 11                  0.386630000                 -0.000910000
# 12                  0.386630000                 -0.000910000
# 13                  0.386630000                 -0.000910000
# 14                  0.386630000                 -0.000910000
#
#     utilitiesChangesPercentage      month1      month3      month6  \
# 10                -0.082430000 0.960000000 4.500000000 4.600000000
# 11                -0.082430000 0.960000000 4.540000000 4.590000000
# 12                -0.082430000 0.960000000 4.530000000 4.570000000
# 13                -0.082430000 0.960000000 4.480000000 4.540000000
# 14                -0.082430000 0.960000000 4.500000000 4.550000000
#
#          year1       year2       year3       year5       year7      year10  \
# 10 4.660000000 4.800000000 4.850000000 4.880000000 5.040000000 4.940000000
# 11 4.660000000 4.800000000 4.840000000 4.860000000 5.030000000 4.940000000
# 12 4.650000000 4.790000000 4.780000000 4.780000000 4.990000000 4.910000000
# 13 4.640000000 4.770000000 4.780000000 4.790000000 4.990000000 4.900000000
# 14 4.660000000 4.800000000 4.820000000 4.830000000 5.010000000 4.930000000
#
#         year20      year30  inflationRate  Palladium_price  Palladium_volume  \
# 10 5.610000000 5.340000000    2.190000000    346.000000000     796.000000000
# 11 5.610000000 5.350000000    2.190000000    346.000000000     691.000000000
# 12 5.580000000 5.330000000    2.190000000    351.500000000     204.000000000
# 13 5.580000000 5.340000000    2.190000000    356.900000000     234.000000000
# 14 5.580000000 5.290000000    2.190000000    354.000000000     377.000000000
#
#     Palladium_open  Palladium_close  Copper_price   Copper_volume  \
# 10   357.000000000    346.000000000   0.666000000 17079.000000000
# 11   343.000000000    346.000000000   0.684500000 13213.000000000
# 12   347.000000000    351.500000000   0.667500000  6155.000000000
# 13   355.000000000    356.900000000   0.662500000  4205.000000000
# 14   357.000000000    354.000000000   0.662500000  4528.000000000
#
#     Copper_open  Copper_close  Lithium_price  Lithium_volume  Lithium_open  \
# 10  0.667000000   0.666000000   11.230894179 29891.782535737  11.263648993
# 11  0.667500000   0.684500000   11.320954342 29891.782535737  11.266076635
# 12  0.677000000   0.667500000   11.238169587 29891.782535737  11.312301369
# 13  0.667000000   0.662500000   11.213936537 29891.782535737  11.263648993
# 14  0.661000000   0.662500000   11.213936537 29891.782535737  11.234558063
#
#     Lithium_close  Silver_price  Silver_volume  Silver_open  Silver_close  \
# 10   11.230894179   5.665000000    0.000000000  5.805000000   5.665000000
# 11   11.320954342   5.610000000    0.000000000  5.660000000   5.610000000
# 12   11.238169587   5.510000000    0.000000000  5.595000000   5.510000000
# 13   11.213936537   5.465000000    0.000000000  5.530000000   5.465000000
# 14   11.213936537   5.565000000    0.000000000  5.470000000   5.565000000
#
#       Gold_price  Gold_volume     Gold_open    Gold_close         sma  \
# 10 288.550000000  0.000000000 289.450000000 288.550000000 0.041276200
# 11 289.150000000  0.000000000 288.750000000 289.150000000 0.039843900
# 12 287.400000000  0.000000000 288.850000000 287.400000000 0.038281400
# 13 287.250000000  0.000000000 287.900000000 287.250000000 0.037890800
# 14 287.700000000  0.000000000 287.050000000 287.700000000 0.041146000
#
#              adx        dema         ema           rsi  standardDeviation  \
# 10 100.000000000 0.041276200 0.041276200 100.000000000        0.000000000
# 11   0.000000000 0.039843900 0.039843900   0.000000000        0.000000000
# 12 100.000000000 0.038281400 0.038281400   0.000000000        0.000000000
# 13 100.000000000 0.037890800 0.037890800   0.000000000        0.000000000
# 14 100.000000000 0.041146000 0.041146000 100.000000000        0.000000000
#
#           tema       williams         wma NVDA_stock_news_sentiment  \
# 10 0.041276200  -20.003071882 0.041276200                   neutral
# 11 0.039843900 -100.000000000 0.039843900                   neutral
# 12 0.038281400  -83.334400000 0.038281400                   neutral
# 13 0.037890800  -68.751500024 0.037890800                   neutral
# 14 0.041146000  -33.333333333 0.041146000           weakly_positive
#
#    NVDA_press_release_sentiment  month  year  season  NVDA_close_lag_1  \
# 10                      neutral      2  1999  Winter      19.250000000
# 11                      neutral      2  1999  Winter      19.810000000
# 12                      neutral      2  1999  Winter      19.130000000
# 13                      neutral      2  1999  Winter      18.380000000
# 14                      neutral      2  1999  Winter      18.190000000
#
#     NVDA_close_lag_2  NVDA_close_lag_3  NVDA_close_lag_4  NVDA_close_lag_5  \
# 10      18.250000000      17.880000000      19.380000000      19.000000000
# 11      19.250000000      18.250000000      17.880000000      19.380000000
# 12      19.810000000      19.250000000      18.250000000      17.880000000
# 13      19.130000000      19.810000000      19.250000000      18.250000000
# 14      18.380000000      19.130000000      19.810000000      19.250000000
#
#     NVDA_close_lag_6  NVDA_close_lag_7  NVDA_close_lag_8  NVDA_close_lag_9  \
# 10      19.940000000      20.000000000      20.060000000      21.750000000
# 11      19.000000000      19.940000000      20.000000000      20.060000000
# 12      19.380000000      19.000000000      19.940000000      20.000000000
# 13      17.880000000      19.380000000      19.000000000      19.940000000
# 14      18.250000000      17.880000000      19.380000000      19.000000000
#
#     NVDA_close_lag_10  Silver_price_lag_1  Silver_price_lag_2  \
# 10       19.690000000         5.765000000         5.535000000
# 11       21.750000000         5.665000000         5.765000000
# 12       20.060000000         5.610000000         5.665000000
# 13       20.000000000         5.510000000         5.610000000
# 14       19.940000000         5.465000000         5.510000000
#
#     Silver_price_lag_3  Silver_price_lag_4  Silver_price_lag_5  \
# 10         5.465000000         5.320000000         5.245000000
# 11         5.535000000         5.465000000         5.320000000
# 12         5.765000000         5.535000000         5.465000000
# 13         5.665000000         5.765000000         5.535000000
# 14         5.610000000         5.665000000         5.765000000
#
#     Silver_price_lag_6  Silver_price_lag_7  Silver_price_lag_8  \
# 10         5.235000000         5.095000000         5.115000000
# 11         5.245000000         5.235000000         5.095000000
# 12         5.320000000         5.245000000         5.235000000
# 13         5.465000000         5.320000000         5.245000000
# 14         5.535000000         5.465000000         5.320000000
#
#     Silver_price_lag_9  Silver_price_lag_10  inflationRate_lag_1  \
# 10         5.185000000          5.115000000          2.190000000
# 11         5.115000000          5.185000000          2.190000000
# 12         5.095000000          5.115000000          2.190000000
# 13         5.235000000          5.095000000          2.190000000
# 14         5.245000000          5.235000000          2.190000000
#
#     inflationRate_lag_2  inflationRate_lag_3  inflationRate_lag_4  \
# 10          2.190000000          2.190000000          2.190000000
# 11          2.190000000          2.190000000          2.190000000
# 12          2.190000000          2.190000000          2.190000000
# 13          2.190000000          2.190000000          2.190000000
# 14          2.190000000          2.190000000          2.190000000
#
#     inflationRate_lag_5  inflationRate_lag_6  inflationRate_lag_7  \
# 10          2.190000000          2.190000000          2.190000000
# 11          2.190000000          2.190000000          2.190000000
# 12          2.190000000          2.190000000          2.190000000
# 13          2.190000000          2.190000000          2.190000000
# 14          2.190000000          2.190000000          2.190000000
#
#     inflationRate_lag_8  inflationRate_lag_9  inflationRate_lag_10  \
# 10          2.190000000          2.190000000           2.190000000
# 11          2.190000000          2.190000000           2.190000000
# 12          2.190000000          2.190000000           2.190000000
# 13          2.190000000          2.190000000           2.190000000
# 14          2.190000000          2.190000000           2.190000000
#
#    NVDA_stock_news_sentiment_lag_1 NVDA_stock_news_sentiment_lag_2  \
# 10                         neutral                 weakly_positive
# 11                         neutral                         neutral
# 12                         neutral                         neutral
# 13                         neutral                         neutral
# 14                         neutral                         neutral
#
#    NVDA_stock_news_sentiment_lag_3 NVDA_stock_news_sentiment_lag_4  \
# 10                         neutral                         neutral
# 11                 weakly_positive                         neutral
# 12                         neutral                 weakly_positive
# 13                         neutral                         neutral
# 14                         neutral                         neutral
#
#    NVDA_stock_news_sentiment_lag_5 NVDA_stock_news_sentiment_lag_6  \
# 10                         neutral                         neutral
# 11                         neutral                         neutral
# 12                         neutral                         neutral
# 13                 weakly_positive                         neutral
# 14                         neutral                 weakly_positive
#
#    NVDA_stock_news_sentiment_lag_7 NVDA_stock_news_sentiment_lag_8  \
# 10                         neutral                         neutral
# 11                         neutral                         neutral
# 12                         neutral                         neutral
# 13                         neutral                         neutral
# 14                         neutral                         neutral
#
#    NVDA_stock_news_sentiment_lag_9 NVDA_stock_news_sentiment_lag_10  \
# 10                         neutral                          neutral
# 11                         neutral                          neutral
# 12                         neutral                          neutral
# 13                         neutral                          neutral
# 14                         neutral                          neutral
#
#     Gold_price_lag_1  Gold_price_lag_2  Gold_price_lag_3  Gold_price_lag_4  \
# 10     289.450000000     287.550000000     288.450000000     288.850000000
# 11     288.550000000     289.450000000     287.550000000     288.450000000
# 12     289.150000000     288.550000000     289.450000000     287.550000000
# 13     287.400000000     289.150000000     288.550000000     289.450000000
# 14     287.250000000     287.400000000     289.150000000     288.550000000
#
#     Gold_price_lag_5  Gold_price_lag_6  Gold_price_lag_7  Gold_price_lag_8  \
# 10     286.150000000     284.250000000     283.000000000     286.150000000
# 11     288.850000000     286.150000000     284.250000000     283.000000000
# 12     288.450000000     288.850000000     286.150000000     284.250000000
# 13     287.550000000     288.450000000     288.850000000     286.150000000
# 14     289.450000000     287.550000000     288.450000000     288.850000000
#
#     Gold_price_lag_9  Gold_price_lag_10 NVDA_press_release_sentiment_lag_1  \
# 10     287.850000000      286.450000000                            neutral
# 11     286.150000000      287.850000000                            neutral
# 12     283.000000000      286.150000000                            neutral
# 13     284.250000000      283.000000000                            neutral
# 14     286.150000000      284.250000000                            neutral
#
#    NVDA_press_release_sentiment_lag_2 NVDA_press_release_sentiment_lag_3  \
# 10                            neutral                            neutral
# 11                            neutral                            neutral
# 12                            neutral                            neutral
# 13                            neutral                            neutral
# 14                            neutral                            neutral
#
#    NVDA_press_release_sentiment_lag_4 NVDA_press_release_sentiment_lag_5  \
# 10                            neutral                            neutral
# 11                            neutral                            neutral
# 12                            neutral                            neutral
# 13                            neutral                            neutral
# 14                            neutral                            neutral
#
#    NVDA_press_release_sentiment_lag_6 NVDA_press_release_sentiment_lag_7  \
# 10                            neutral                            neutral
# 11                            neutral                            neutral
# 12                            neutral                            neutral
# 13                            neutral                            neutral
# 14                            neutral                            neutral
#
#    NVDA_press_release_sentiment_lag_8 NVDA_press_release_sentiment_lag_9  \
# 10                            neutral                            neutral
# 11                            neutral                            neutral
# 12                            neutral                            neutral
# 13                            neutral                            neutral
# 14                            neutral                            neutral
#
#    NVDA_press_release_sentiment_lag_10  day
# 10                             neutral    5
# 11                             neutral    8
# 12                             neutral    9
# 13                             neutral   10
# 14                             neutral   11

# %%
nvda_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6593 entries, 10 to 6639
# Columns: 129 entries, date to day
# dtypes: datetime64[ns](1), float64(100), int32(3), int64(2), object(23)
# memory usage: 6.5+ MB

# %%
# Obtainig Dummies
nvda_data = pd.get_dummies(nvda_data, drop_first=True)

num_cols = list(nvda_data.select_dtypes(include=['float64', 'int64', 'int32']).columns)

num_cols.remove('NVDA_close')

print(num_cols)

print(len(num_cols), len(nvda_data.columns))
# Out:
# ['NVDA_high', 'NVDA_low', 'NVDA_open', 'NVDA_traded_volume', 'NVDA_adjClose', 'NVDA_adjLow', 'NVDA_adjOpen', 'NVDA_adj_traded_volume', 'NVDA_divCash', 'NVDA_splitFactor', 'pe', 'communicationServicesChangesPercentage', 'consumerCyclicalChangesPercentage', 'consumerDefensiveChangesPercentage', 'energyChangesPercentage', 'healthcareChangesPercentage', 'industrialsChangesPercentage', 'realEstateChangesPercentage', 'technologyChangesPercentage', 'utilitiesChangesPercentage', 'month1', 'month3', 'month6', 'year1', 'year2', 'year3', 'year5', 'year7', 'year10', 'year20', 'year30', 'inflationRate', 'Palladium_price', 'Palladium_volume', 'Palladium_open', 'Palladium_close', 'Copper_price', 'Copper_volume', 'Copper_open', 'Copper_close', 'Lithium_price', 'Lithium_volume', 'Lithium_open', 'Lithium_close', 'Silver_price', 'Silver_volume', 'Silver_open', 'Silver_close', 'Gold_price', 'Gold_volume', 'Gold_open', 'Gold_close', 'sma', 'adx', 'dema', 'ema', 'rsi', 'standardDeviation', 'tema', 'williams', 'wma', 'month', 'year', 'NVDA_close_lag_1', 'NVDA_close_lag_2', 'NVDA_close_lag_3', 'NVDA_close_lag_4', 'NVDA_close_lag_5', 'NVDA_close_lag_6', 'NVDA_close_lag_7', 'NVDA_close_lag_8', 'NVDA_close_lag_9', 'NVDA_close_lag_10', 'Silver_price_lag_1', 'Silver_price_lag_2', 'Silver_price_lag_3', 'Silver_price_lag_4', 'Silver_price_lag_5', 'Silver_price_lag_6', 'Silver_price_lag_7', 'Silver_price_lag_8', 'Silver_price_lag_9', 'Silver_price_lag_10', 'inflationRate_lag_1', 'inflationRate_lag_2', 'inflationRate_lag_3', 'inflationRate_lag_4', 'inflationRate_lag_5', 'inflationRate_lag_6', 'inflationRate_lag_7', 'inflationRate_lag_8', 'inflationRate_lag_9', 'inflationRate_lag_10', 'Gold_price_lag_1', 'Gold_price_lag_2', 'Gold_price_lag_3', 'Gold_price_lag_4', 'Gold_price_lag_5', 'Gold_price_lag_6', 'Gold_price_lag_7', 'Gold_price_lag_8', 'Gold_price_lag_9', 'Gold_price_lag_10', 'day']
# 104 197

# %%
# Normalize the data as stock prices have a lower bound of zero
scaler = MinMaxScaler(feature_range=(0, 1))

nvda_data[num_cols] = scaler.fit_transform(nvda_data[num_cols])

nvda_data.head()
# Out:
#          date   NVDA_close   NVDA_high    NVDA_low   NVDA_open  \
# 10 1999-02-05 19.810000000 0.010900447 0.011304089 0.010984382
# 11 1999-02-08 19.130000000 0.010900447 0.011363540 0.011292204
# 12 1999-02-09 18.380000000 0.010604327 0.010514247 0.010935779
# 13 1999-02-10 18.190000000 0.010004082 0.010301924 0.010028514
# 14 1999-02-11 19.750000000 0.011300611 0.010616162 0.009923207
#
#     NVDA_traded_volume  NVDA_adjClose  NVDA_adjLow  NVDA_adjOpen  \
# 10         0.000026440    0.000043869  0.000039563   0.000035094
# 11         0.000030328    0.000035172  0.000040468   0.000039840
# 12         0.000015186    0.000025580  0.000027539   0.000034345
# 13         0.000029007    0.000023150  0.000024307   0.000020357
# 14         0.000025400    0.000043102  0.000029091   0.000018734
#
#     NVDA_adj_traded_volume  NVDA_divCash  NVDA_splitFactor          pe  \
# 10             0.000317293   0.000000000       0.000000000 0.199726711
# 11             0.000363958   0.000000000       0.000000000 0.199726711
# 12             0.000182239   0.000000000       0.000000000 0.199726711
# 13             0.000348100   0.000000000       0.000000000 0.199726711
# 14             0.000304815   0.000000000       0.000000000 0.199726711
#
#     communicationServicesChangesPercentage  consumerCyclicalChangesPercentage  \
# 10                             0.400103511                        0.398676997
# 11                             0.400103511                        0.398676997
# 12                             0.400103511                        0.398676997
# 13                             0.400103511                        0.398676997
# 14                             0.400103511                        0.398676997
#
#     consumerDefensiveChangesPercentage  energyChangesPercentage  \
# 10                         0.505741961              0.575991393
# 11                         0.505741961              0.575991393
# 12                         0.505741961              0.575991393
# 13                         0.505741961              0.575991393
# 14                         0.505741961              0.575991393
#
#     healthcareChangesPercentage  industrialsChangesPercentage  \
# 10                  0.501024559                   0.543689448
# 11                  0.501024559                   0.543689448
# 12                  0.501024559                   0.543689448
# 13                  0.501024559                   0.543689448
# 14                  0.501024559                   0.543689448
#
#     realEstateChangesPercentage  technologyChangesPercentage  \
# 10                  0.533448035                  0.559926492
# 11                  0.533448035                  0.559926492
# 12                  0.533448035                  0.559926492
# 13                  0.533448035                  0.559926492
# 14                  0.533448035                  0.559926492
#
#     utilitiesChangesPercentage      month1      month3      month6  \
# 10                 0.418464329 0.159468439 0.700934579 0.701378254
# 11                 0.418464329 0.159468439 0.707165109 0.699846861
# 12                 0.418464329 0.159468439 0.705607477 0.696784074
# 13                 0.418464329 0.159468439 0.697819315 0.692189893
# 14                 0.418464329 0.159468439 0.700934579 0.693721286
#
#          year1       year2       year3       year5       year7      year10  \
# 10 0.721875000 0.688596491 0.700589971 0.706325301 0.718894009 0.704944179
# 11 0.721875000 0.688596491 0.699115044 0.703313253 0.717357911 0.704944179
# 12 0.720312500 0.687134503 0.690265487 0.691265060 0.711213518 0.700159490
# 13 0.718750000 0.684210526 0.690265487 0.692771084 0.711213518 0.698564593
# 14 0.721875000 0.688596491 0.696165192 0.698795181 0.714285714 0.703349282
#
#         year20      year30  inflationRate  Palladium_price  Palladium_volume  \
# 10 0.777049180 0.755208333    0.721476510      0.069704242       0.051258935
# 11 0.777049180 0.756944444    0.721476510      0.069704242       0.044497392
# 12 0.772131148 0.753472222    0.721476510      0.071645373       0.013136712
# 13 0.772131148 0.755208333    0.721476510      0.073551211       0.015068581
# 14 0.772131148 0.746527778    0.721476510      0.072527705       0.024277159
#
#     Palladium_open  Palladium_close  Copper_price  Copper_volume  Copper_open  \
# 10     0.069435216      0.069704242   0.013333333    0.062619459  0.013551039
# 11     0.064784053      0.069704242   0.017444444    0.048436623  0.013662113
# 12     0.066112957      0.071645373   0.013666667    0.022543592  0.015772520
# 13     0.068770764      0.073551211   0.012555556    0.015389808  0.013551039
# 14     0.069435216      0.072527705   0.012555556    0.016574768  0.012218150
#
#     Copper_close  Lithium_price  Lithium_volume  Lithium_open  Lithium_close  \
# 10   0.013333333    0.003364167     0.005644447   0.003407390    0.003364167
# 11   0.017444444    0.004419152     0.005644447   0.003435691    0.004419152
# 12   0.013666667    0.003449393     0.005644447   0.003974575    0.003449393
# 13   0.012555556    0.003165521     0.005644447   0.003407390    0.003165521
# 14   0.012555556    0.003165521     0.005644447   0.003068250    0.003165521
#
#     Silver_price  Silver_volume  Silver_open  Silver_close  Gold_price  \
# 10   0.036173090    0.000000000  0.039111812   0.036173090 0.013331605
# 11   0.034933514    0.000000000  0.035843102   0.034933514 0.013553799
# 12   0.032679739    0.000000000  0.034377818   0.032679739 0.012905734
# 13   0.031665540    0.000000000  0.032912534   0.031665540 0.012850186
# 14   0.033919315    0.000000000  0.031559964   0.033919315 0.013016831
#
#     Gold_volume   Gold_open  Gold_close         sma         adx        dema  \
# 10  0.000000000 0.013737942 0.013331605 0.000047936 1.000000000 0.000047936
# 11  0.000000000 0.013478736 0.013553799 0.000038348 0.000000000 0.000038348
# 12  0.000000000 0.013515765 0.012905734 0.000027890 1.000000000 0.000027890
# 13  0.000000000 0.013163985 0.012850186 0.000025275 1.000000000 0.000025275
# 14  0.000000000 0.012849234 0.013016831 0.000047064 1.000000000 0.000047064
#
#            ema         rsi  standardDeviation        tema    williams  \
# 10 0.000047936 1.000000000        0.000000000 0.000047936 0.799969281
# 11 0.000038348 0.000000000        0.000000000 0.000038348 0.000000000
# 12 0.000027890 0.000000000        0.000000000 0.000027890 0.166656000
# 13 0.000025275 0.000000000        0.000000000 0.000025275 0.312485000
# 14 0.000047064 1.000000000        0.000000000 0.000047064 0.666666667
#
#            wma       month        year  NVDA_close_lag_1  NVDA_close_lag_2  \
# 10 0.000047936 0.090909091 0.000000000       0.010956094       0.010135412
# 11 0.000038348 0.090909091 0.000000000       0.011415675       0.010956094
# 12 0.000027890 0.090909091 0.000000000       0.010857612       0.011415675
# 13 0.000025275 0.090909091 0.000000000       0.010242101       0.010857612
# 14 0.000047064 0.090909091 0.000000000       0.010086172       0.010242101
#
#     NVDA_close_lag_3  NVDA_close_lag_4  NVDA_close_lag_5  NVDA_close_lag_6  \
# 10       0.009831760       0.011062782       0.010750923       0.011522364
# 11       0.010135412       0.009831760       0.011062782       0.010750923
# 12       0.010956094       0.010135412       0.009831760       0.011062782
# 13       0.011415675       0.010956094       0.010135412       0.009831760
# 14       0.010857612       0.011415675       0.010956094       0.010135412
#
#     NVDA_close_lag_7  NVDA_close_lag_8  NVDA_close_lag_9  NVDA_close_lag_10  \
# 10       0.011571604       0.011620845       0.013007796        0.011317193
# 11       0.011522364       0.011571604       0.011620845        0.013007796
# 12       0.010750923       0.011522364       0.011571604        0.011620845
# 13       0.011062782       0.010750923       0.011522364        0.011571604
# 14       0.009831760       0.011062782       0.010750923        0.011522364
#
#     Silver_price_lag_1  Silver_price_lag_2  Silver_price_lag_3  \
# 10         0.038426865         0.033243182         0.031665540
# 11         0.036173090         0.038426865         0.033243182
# 12         0.034933514         0.036173090         0.038426865
# 13         0.032679739         0.034933514         0.036173090
# 14         0.031665540         0.032679739         0.034933514
#
#     Silver_price_lag_4  Silver_price_lag_5  Silver_price_lag_6  \
# 10         0.028397566         0.026707235         0.026481857
# 11         0.031665540         0.028397566         0.026707235
# 12         0.033243182         0.031665540         0.028397566
# 13         0.038426865         0.033243182         0.031665540
# 14         0.036173090         0.038426865         0.033243182
#
#     Silver_price_lag_7  Silver_price_lag_8  Silver_price_lag_9  \
# 10         0.023326572         0.023777327         0.025354970
# 11         0.026481857         0.023326572         0.023777327
# 12         0.026707235         0.026481857         0.023326572
# 13         0.028397566         0.026707235         0.026481857
# 14         0.031665540         0.028397566         0.026707235
#
#     Silver_price_lag_10  inflationRate_lag_1  inflationRate_lag_2  \
# 10          0.023777327          0.721476510          0.721476510
# 11          0.025354970          0.721476510          0.721476510
# 12          0.023777327          0.721476510          0.721476510
# 13          0.023326572          0.721476510          0.721476510
# 14          0.026481857          0.721476510          0.721476510
#
#     inflationRate_lag_3  inflationRate_lag_4  inflationRate_lag_5  \
# 10          0.721476510          0.721476510          0.721476510
# 11          0.721476510          0.721476510          0.721476510
# 12          0.721476510          0.721476510          0.721476510
# 13          0.721476510          0.721476510          0.721476510
# 14          0.721476510          0.721476510          0.721476510
#
#     inflationRate_lag_6  inflationRate_lag_7  inflationRate_lag_8  \
# 10          0.721476510          0.721476510          0.721476510
# 11          0.721476510          0.721476510          0.721476510
# 12          0.721476510          0.721476510          0.721476510
# 13          0.721476510          0.721476510          0.721476510
# 14          0.721476510          0.721476510          0.721476510
#
#     inflationRate_lag_9  inflationRate_lag_10  Gold_price_lag_1  \
# 10          0.721476510           0.721476510       0.013664895
# 11          0.721476510           0.721476510       0.013331605
# 12          0.721476510           0.721476510       0.013553799
# 13          0.721476510           0.721476510       0.012905734
# 14          0.721476510           0.721476510       0.012850186
#
#     Gold_price_lag_2  Gold_price_lag_3  Gold_price_lag_4  Gold_price_lag_5  \
# 10       0.012961283       0.013294573       0.013442702       0.012442831
# 11       0.013664895       0.012961283       0.013294573       0.013442702
# 12       0.013331605       0.013664895       0.012961283       0.013294573
# 13       0.013553799       0.013331605       0.013664895       0.012961283
# 14       0.012905734       0.013553799       0.013331605       0.013664895
#
#     Gold_price_lag_6  Gold_price_lag_7  Gold_price_lag_8  Gold_price_lag_9  \
# 10       0.011739219       0.011333859       0.012506328       0.013157748
# 11       0.012442831       0.011799125       0.011333859       0.012524088
# 12       0.013442702       0.012506328       0.011799125       0.011349955
# 13       0.013294573       0.013511300       0.012506328       0.011815881
# 14       0.012961283       0.013362416       0.013511300       0.012524088
#
#     Gold_price_lag_10         day  \
# 10        0.012635911 0.133333333
# 11        0.013157748 0.233333333
# 12        0.012524088 0.266666667
# 13        0.011349955 0.300000000
# 14        0.011815881 0.333333333
#
#     NVDA_stock_news_sentiment_strongly_negative  \
# 10                                        False
# 11                                        False
# 12                                        False
# 13                                        False
# 14                                        False
#
#     NVDA_stock_news_sentiment_strongly_positive  \
# 10                                        False
# 11                                        False
# 12                                        False
# 13                                        False
# 14                                        False
#
#     NVDA_stock_news_sentiment_weakly_negative  \
# 10                                      False
# 11                                      False
# 12                                      False
# 13                                      False
# 14                                      False
#
#     NVDA_stock_news_sentiment_weakly_positive  \
# 10                                      False
# 11                                      False
# 12                                      False
# 13                                      False
# 14                                       True
#
#     NVDA_press_release_sentiment_strongly_negative  \
# 10                                           False
# 11                                           False
# 12                                           False
# 13                                           False
# 14                                           False
#
#     NVDA_press_release_sentiment_strongly_positive  \
# 10                                           False
# 11                                           False
# 12                                           False
# 13                                           False
# 14                                           False
#
#     NVDA_press_release_sentiment_weakly_negative  \
# 10                                         False
# 11                                         False
# 12                                         False
# 13                                         False
# 14                                         False
#
#     NVDA_press_release_sentiment_weakly_positive  season_Spring  \
# 10                                         False          False
# 11                                         False          False
# 12                                         False          False
# 13                                         False          False
# 14                                         False          False
#
#     season_Summer  season_Winter  \
# 10          False           True
# 11          False           True
# 12          False           True
# 13          False           True
# 14          False           True
#
#     NVDA_stock_news_sentiment_lag_1_strongly_negative  \
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
#
#     NVDA_stock_news_sentiment_lag_1_strongly_positive  \
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
#
#     NVDA_stock_news_sentiment_lag_1_weakly_negative  \
# 10                                            False
# 11                                            False
# 12                                            False
# 13                                            False
# 14                                            False
#
#     NVDA_stock_news_sentiment_lag_1_weakly_positive  \
# 10                                            False
# 11                                            False
# 12                                            False
# 13                                            False
# 14                                            False
#
#     NVDA_stock_news_sentiment_lag_2_strongly_negative  \
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
#
#     NVDA_stock_news_sentiment_lag_2_strongly_positive  \
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
#
#     NVDA_stock_news_sentiment_lag_2_weakly_negative  \
# 10                                            False
# 11                                            False
# 12                                            False
# 13                                            False
# 14                                            False
#
#     NVDA_stock_news_sentiment_lag_2_weakly_positive  \
# 10                                             True
# 11                                            False
# 12                                            False
# 13                                            False
# 14                                            False
#
#     NVDA_stock_news_sentiment_lag_3_strongly_negative  \
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
#
#     NVDA_stock_news_sentiment_lag_3_strongly_positive  \
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
#
#     NVDA_stock_news_sentiment_lag_3_weakly_negative  \
# 10                                            False
# 11                                            False
# 12                                            False
# 13                                            False
# 14                                            False
#
#     NVDA_stock_news_sentiment_lag_3_weakly_positive  \
# 10                                            False
# 11                                             True
# 12                                            False
# 13                                            False
# 14                                            False
#
#     NVDA_stock_news_sentiment_lag_4_strongly_negative  \
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
#
#     NVDA_stock_news_sentiment_lag_4_strongly_positive  \
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
#
#     NVDA_stock_news_sentiment_lag_4_weakly_negative  \
# 10                                            False
# 11                                            False
# 12                                            False
# 13                                            False
# 14                                            False
#
#     NVDA_stock_news_sentiment_lag_4_weakly_positive  \
# 10                                            False
# 11                                            False
# 12                                             True
# 13                                            False
# 14                                            False
#
#     NVDA_stock_news_sentiment_lag_5_strongly_negative  \
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
#
#     NVDA_stock_news_sentiment_lag_5_strongly_positive  \
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
#
#     NVDA_stock_news_sentiment_lag_5_weakly_negative  \
# 10                                            False
# 11                                            False
# 12                                            False
# 13                                            False
# 14                                            False
#
#     NVDA_stock_news_sentiment_lag_5_weakly_positive  \
# 10                                            False
# 11                                            False
# 12                                            False
# 13                                             True
# 14                                            False
#
#     NVDA_stock_news_sentiment_lag_6_strongly_negative  \
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
#
#     NVDA_stock_news_sentiment_lag_6_strongly_positive  \
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
#
#     NVDA_stock_news_sentiment_lag_6_weakly_negative  \
# 10                                            False
# 11                                            False
# 12                                            False
# 13                                            False
# 14                                            False
#
#     NVDA_stock_news_sentiment_lag_6_weakly_positive  \
# 10                                            False
# 11                                            False
# 12                                            False
# 13                                            False
# 14                                             True
#
#     NVDA_stock_news_sentiment_lag_7_strongly_negative  \
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
#
#     NVDA_stock_news_sentiment_lag_7_strongly_positive  \
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
#
#     NVDA_stock_news_sentiment_lag_7_weakly_negative  \
# 10                                            False
# 11                                            False
# 12                                            False
# 13                                            False
# 14                                            False
#
#     NVDA_stock_news_sentiment_lag_7_weakly_positive  \
# 10                                            False
# 11                                            False
# 12                                            False
# 13                                            False
# 14                                            False
#
#     NVDA_stock_news_sentiment_lag_8_strongly_negative  \
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
#
#     NVDA_stock_news_sentiment_lag_8_strongly_positive  \
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
#
#     NVDA_stock_news_sentiment_lag_8_weakly_negative  \
# 10                                            False
# 11                                            False
# 12                                            False
# 13                                            False
# 14                                            False
#
#     NVDA_stock_news_sentiment_lag_8_weakly_positive  \
# 10                                            False
# 11                                            False
# 12                                            False
# 13                                            False
# 14                                            False
#
#     NVDA_stock_news_sentiment_lag_9_strongly_negative  \
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
#
#     NVDA_stock_news_sentiment_lag_9_strongly_positive  \
# 10                                              False
# 11                                              False
# 12                                              False
# 13                                              False
# 14                                              False
#
#     NVDA_stock_news_sentiment_lag_9_weakly_negative  \
# 10                                            False
# 11                                            False
# 12                                            False
# 13                                            False
# 14                                            False
#
#     NVDA_stock_news_sentiment_lag_9_weakly_positive  \
# 10                                            False
# 11                                            False
# 12                                            False
# 13                                            False
# 14                                            False
#
#     NVDA_stock_news_sentiment_lag_10_strongly_negative  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_stock_news_sentiment_lag_10_strongly_positive  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_stock_news_sentiment_lag_10_weakly_negative  \
# 10                                             False
# 11                                             False
# 12                                             False
# 13                                             False
# 14                                             False
#
#     NVDA_stock_news_sentiment_lag_10_weakly_positive  \
# 10                                             False
# 11                                             False
# 12                                             False
# 13                                             False
# 14                                             False
#
#     NVDA_press_release_sentiment_lag_1_strongly_negative  \
# 10                                                 False
# 11                                                 False
# 12                                                 False
# 13                                                 False
# 14                                                 False
#
#     NVDA_press_release_sentiment_lag_1_strongly_positive  \
# 10                                                 False
# 11                                                 False
# 12                                                 False
# 13                                                 False
# 14                                                 False
#
#     NVDA_press_release_sentiment_lag_1_weakly_negative  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_press_release_sentiment_lag_1_weakly_positive  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_press_release_sentiment_lag_2_strongly_negative  \
# 10                                                 False
# 11                                                 False
# 12                                                 False
# 13                                                 False
# 14                                                 False
#
#     NVDA_press_release_sentiment_lag_2_strongly_positive  \
# 10                                                 False
# 11                                                 False
# 12                                                 False
# 13                                                 False
# 14                                                 False
#
#     NVDA_press_release_sentiment_lag_2_weakly_negative  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_press_release_sentiment_lag_2_weakly_positive  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_press_release_sentiment_lag_3_strongly_negative  \
# 10                                                 False
# 11                                                 False
# 12                                                 False
# 13                                                 False
# 14                                                 False
#
#     NVDA_press_release_sentiment_lag_3_strongly_positive  \
# 10                                                 False
# 11                                                 False
# 12                                                 False
# 13                                                 False
# 14                                                 False
#
#     NVDA_press_release_sentiment_lag_3_weakly_negative  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_press_release_sentiment_lag_3_weakly_positive  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_press_release_sentiment_lag_4_strongly_negative  \
# 10                                                 False
# 11                                                 False
# 12                                                 False
# 13                                                 False
# 14                                                 False
#
#     NVDA_press_release_sentiment_lag_4_strongly_positive  \
# 10                                                 False
# 11                                                 False
# 12                                                 False
# 13                                                 False
# 14                                                 False
#
#     NVDA_press_release_sentiment_lag_4_weakly_negative  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_press_release_sentiment_lag_4_weakly_positive  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_press_release_sentiment_lag_5_strongly_negative  \
# 10                                                 False
# 11                                                 False
# 12                                                 False
# 13                                                 False
# 14                                                 False
#
#     NVDA_press_release_sentiment_lag_5_strongly_positive  \
# 10                                                 False
# 11                                                 False
# 12                                                 False
# 13                                                 False
# 14                                                 False
#
#     NVDA_press_release_sentiment_lag_5_weakly_negative  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_press_release_sentiment_lag_5_weakly_positive  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_press_release_sentiment_lag_6_strongly_negative  \
# 10                                                 False
# 11                                                 False
# 12                                                 False
# 13                                                 False
# 14                                                 False
#
#     NVDA_press_release_sentiment_lag_6_strongly_positive  \
# 10                                                 False
# 11                                                 False
# 12                                                 False
# 13                                                 False
# 14                                                 False
#
#     NVDA_press_release_sentiment_lag_6_weakly_negative  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_press_release_sentiment_lag_6_weakly_positive  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_press_release_sentiment_lag_7_strongly_negative  \
# 10                                                 False
# 11                                                 False
# 12                                                 False
# 13                                                 False
# 14                                                 False
#
#     NVDA_press_release_sentiment_lag_7_strongly_positive  \
# 10                                                 False
# 11                                                 False
# 12                                                 False
# 13                                                 False
# 14                                                 False
#
#     NVDA_press_release_sentiment_lag_7_weakly_negative  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_press_release_sentiment_lag_7_weakly_positive  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_press_release_sentiment_lag_8_strongly_negative  \
# 10                                                 False
# 11                                                 False
# 12                                                 False
# 13                                                 False
# 14                                                 False
#
#     NVDA_press_release_sentiment_lag_8_strongly_positive  \
# 10                                                 False
# 11                                                 False
# 12                                                 False
# 13                                                 False
# 14                                                 False
#
#     NVDA_press_release_sentiment_lag_8_weakly_negative  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_press_release_sentiment_lag_8_weakly_positive  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_press_release_sentiment_lag_9_strongly_negative  \
# 10                                                 False
# 11                                                 False
# 12                                                 False
# 13                                                 False
# 14                                                 False
#
#     NVDA_press_release_sentiment_lag_9_strongly_positive  \
# 10                                                 False
# 11                                                 False
# 12                                                 False
# 13                                                 False
# 14                                                 False
#
#     NVDA_press_release_sentiment_lag_9_weakly_negative  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_press_release_sentiment_lag_9_weakly_positive  \
# 10                                               False
# 11                                               False
# 12                                               False
# 13                                               False
# 14                                               False
#
#     NVDA_press_release_sentiment_lag_10_strongly_negative  \
# 10                                                  False
# 11                                                  False
# 12                                                  False
# 13                                                  False
# 14                                                  False
#
#     NVDA_press_release_sentiment_lag_10_strongly_positive  \
# 10                                                  False
# 11                                                  False
# 12                                                  False
# 13                                                  False
# 14                                                  False
#
#     NVDA_press_release_sentiment_lag_10_weakly_negative  \
# 10                                                False
# 11                                                False
# 12                                                False
# 13                                                False
# 14                                                False
#
#     NVDA_press_release_sentiment_lag_10_weakly_positive
# 10                                                False
# 11                                                False
# 12                                                False
# 13                                                False
# 14                                                False

# %% [markdown]
# # Lasso (Baseline) Model For Nvidia

# %%
np.random.seed(42)
random.seed(42)
tf.random.set_seed(42)

# %%
# Step 2: Split the data based on a date threshold ( using the 80th percentile of dates as the split point)
split_date = nvda_data['date'].quantile(0.85) 
train_data = nvda_data[nvda_data['date'] <= split_date]
test_data = nvda_data[nvda_data['date'] > split_date]


# creating response and predictor features
X = train_data.drop(columns=["NVDA_close"]) 
y = train_data["NVDA_close"]

x_test = test_data.drop(columns=['NVDA_close'])
y_test = test_data['NVDA_close']

# %%
final_lasso = Lasso(alpha= 0.001, max_iter=25000)

# tuned_lasso.alpha_ 0.0126

X["date"] = X["date"].astype("int64") // 10**9  # Convert to seconds

final_lasso.fit(X, y)

x_test["date"] = x_test["date"].astype('int64') // 10**9  # Converts to Unix timestamp (seconds)

y_pred = final_lasso.predict(x_test)

rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print(f"Test RMSE: {rmse}")
# Out:
# Test RMSE: 4.867997496145838
# c:\Users\ekf98\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.310e+04, tolerance: 6.583e+03
#   model = cd_fast.enet_coordinate_descent(

# %%
# timeSeriesSplit for cross-validation
tscv = TimeSeriesSplit(n_splits=3)

# Store actual and predicted values
all_dates = []
all_actuals = []
all_preds = []


final_lasso = Lasso(alpha=0.001, max_iter=25000)

X['date'] = train_data['date']

X["date"] = X["date"].astype('int64') // 10**9  # Converts to Unix timestamp (seconds)

# cross-validation loop
for train, valid in tscv.split(X):
    x_train, x_valid = X.iloc[train], X.iloc[valid]
    y_train, y_valid = y.iloc[train], y.iloc[valid]

    
    final_lasso.fit(x_train, y_train)
    y_pred = final_lasso.predict(x_valid)

    # Collect results
    all_dates.extend(x_valid['date'])
    all_actuals.extend(y_valid)
    all_preds.extend(y_pred)

    # Calculating performance
    rmse = np.sqrt(mean_squared_error(y_valid, y_pred))
    print(f'Validation RMSE: {rmse}')

# Create DataFrame for plotting
results_df = pd.DataFrame({'Date': all_dates, 'Actual': all_actuals, 'Predicted': all_preds})

results_df['Date'] = pd.to_datetime(results_df['Date'], unit='s')

# Plot actual vs. predicted prices
plt.figure(figsize=(12, 6))
sns.lineplot(data=results_df, x='Date', y='Actual', label='Actual Prices', color='blue')
sns.lineplot(data=results_df, x='Date', y='Predicted', label='Predicted Prices', color='red', linestyle='dashed')

plt.xlabel("Date")
plt.ylabel("NVDA Close Price")
plt.title("Lasso Actual vs Predicted NVDA Close Prices")
plt.legend()
plt.xticks(rotation=45)
plt.show()
# Out:
# Validation RMSE: 0.8198140260470591
# Validation RMSE: 0.5285049316180822
# Validation RMSE: 3.7902746476252385

# %%
x_test = test_data.drop(columns=['NVDA_close'])
x_test["date"] = x_test["date"].astype('int64') // 10**9  # Converts to Unix timestamp (seconds)

y_test = test_data['NVDA_close']


final_lasso.fit(X, y)
y_pred = final_lasso.predict(x_test)


# Compute RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f'Test RMSE: {rmse}')

x_test['date'] = pd.to_datetime(x_test['date'], unit='s')

# Create DataFrame for test data results
test_results_df = pd.DataFrame({'Date': x_test['date'], 'Actual': y_test, 'Predicted': y_pred})

# Plot actual vs. predicted prices for test data
plt.figure(figsize=(12, 6))
sns.lineplot(data=test_results_df, x='Date', y='Actual', label='Actual Prices', color='blue')
sns.lineplot(data=test_results_df, x='Date', y='Predicted', label='Predicted Prices', color='red', linestyle='dashed')

plt.xlabel("Date")
plt.ylabel("NVDA Close Price")
plt.title("Lasso Actual vs Predicted NVDA Close Prices (Test Data)")
plt.legend()
plt.xticks(rotation=45)
plt.show()



#################### ----------------------------------------------------------- ##############
# Generating Forecast for the Next 3 Weeks (21 days)

# Convert 'date' to datetime before finding the max date
x_test['date'] = pd.to_datetime(x_test['date'])

# Find the last date in the dataset
last_date = x_test['date'].max()

# Create a new date range for the next 21 days
future_dates = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=21, freq='B')


# Initialize the forecast list
forecast_xgb = []

# Use the entire x_test data for the first prediction
last_known_data = x_test.values

for _ in range(15):  # Forecasting for the next 15 trading days
    # Convert Timestamp to numeric (Unix timestamp) if necessary
    if isinstance(last_known_data[0, 0], pd.Timestamp):
        last_known_data[:, 0] = np.array([t.timestamp() for t in last_known_data[:, 0]])

     # Ensure data is float type
    last_known_data = last_known_data.astype(float)

    # Predict the next value using the entire dataset
    pred = final_lasso.predict(last_known_data)[-1]  # Use the last prediction from the model's output
    pred = max(pred, 0)  # Ensure the prediction is not negative
    forecast_xgb.append(pred)
    
    # Append the new prediction to the last_known_data
    new_row = np.roll(last_known_data[-1], -1)  # Shift the last row
    new_row[-1] = pred  # Add the new prediction to the last position
    last_known_data = np.vstack([last_known_data, new_row])  # Append the new row to the dataset

# Create a DataFrame for future dates
future_df = pd.DataFrame({'date': future_dates[:15],  # Assuming future_dates has at least 15 dates
                          'forecasted_prices': forecast_xgb})


# Plot forecasted prices
plt.figure(figsize=(12, 6))
sns.lineplot(data=future_df, x='date', y='forecasted_prices', label='Forecasted Prices', color='blue')

plt.xlabel("Date")
plt.ylabel("NVDA Close Price")
plt.title("Lasso Forecasted NVDA Close Prices for Next 15 Trading Days")
plt.legend()
plt.xticks(rotation=45)
plt.show()
# Out:
# c:\Users\ekf98\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:697: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.310e+04, tolerance: 6.583e+03
#   model = cd_fast.enet_coordinate_descent(
# Test RMSE: 4.867997496145838
# c:\Users\ekf98\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# c:\Users\ekf98\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# c:\Users\ekf98\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# c:\Users\ekf98\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# c:\Users\ekf98\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# c:\Users\ekf98\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# c:\Users\ekf98\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# c:\Users\ekf98\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# c:\Users\ekf98\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# c:\Users\ekf98\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# c:\Users\ekf98\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# c:\Users\ekf98\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# c:\Users\ekf98\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# c:\Users\ekf98\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(
# c:\Users\ekf98\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Lasso was fitted with feature names
#   warnings.warn(

# %%
nvidia_march_prices = pd.read_csv("march_prices/NVDA_march_prices.csv")


nvidia_lasso = pd.concat([future_df, nvidia_march_prices['NVDA_close']], axis=1)

print(f" {nvidia_lasso} \n")

# Assuming you have two columns: 'forecasted_prices' and 'NVDA_close'
correlation, p_value = pearsonr(nvidia_lasso['forecasted_prices'], nvidia_lasso['NVDA_close'])

# Calculate Spearman's correlation
spearman_corr, p_value_spear = spearmanr(nvidia_lasso['forecasted_prices'], nvidia_lasso['NVDA_close'])


# Calculate Pearson correlation
correlation = nvidia_lasso[['forecasted_prices', 'NVDA_close']].corr().iloc[0, 1]


rmse = np.sqrt(np.mean((nvidia_lasso['NVDA_close'] - nvidia_lasso['forecasted_prices'])**2)) # for our given stock price ranges, rmse between 5-10 is good but the lower the better

mae = np.mean(np.abs((nvidia_lasso['NVDA_close'] - nvidia_lasso['forecasted_prices']))) # similarly for mae, the lower the better

mape = np.mean(np.abs((nvidia_lasso['NVDA_close'] - nvidia_lasso['forecasted_prices']) / nvidia_lasso['NVDA_close'])) * 100 # aim for mape below 10% if possible


# Prioritising correlation overall is key. Hopefully the ARIMA model beats this correlation and improves the other metrics as well

print(f"Pearson Correlation between forecasted prices and actual prices: {correlation}  with a p-value of: {p_value} \n",
      f"Spearman Correlation between forecasted prices and actual prices: {spearman_corr}  with a p-value of: {p_value_spear} \n", 
       
      f"Forecasted Root Mean Squared Error: {rmse} \n",
      f"Forecasted Mean Absolute Error: {mae} \n",
      f"Mean Absolute Percentage Error: {mape} \n")

# reshaping data for plotting in seaborn
nvidia_melted = nvidia_lasso.melt(id_vars=['date'],
                               value_vars=['NVDA_close', 'forecasted_prices'],
                               var_name='Date',
                               value_name='Price')

# Plotting in Seaborn
plt.figure(figsize=(9, 8))
sns.lineplot(data=nvidia_melted, x='date', y='Price', hue='Date', markers='o')

# labels
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Actual Versus Forecasted Nvidia Stock Prices in March')
plt.xticks(rotation=45)
plt.grid(True)

plt.show()
# Out:
#           date  forecasted_prices    NVDA_close
# 0  2025-03-05      114.877824864 117.300000000
# 1  2025-03-06      104.205907523 110.570000000
# 2  2025-03-07       78.086858100 112.690000000
# 3  2025-03-10      531.930816747 106.980000000
# 4  2025-03-11      888.424721668 108.760000000
# 5  2025-03-12      851.290953895 115.740000000
# 6  2025-03-13      390.691093459 115.580000000
# 7  2025-03-14       13.472200469 121.670000000
# 8  2025-03-17        0.000000000 119.530000000
# 9  2025-03-18      129.096380757 115.430000000
# 10 2025-03-19      397.535250089 117.520000000
# 11 2025-03-20      194.284602830 118.530000000
# 12 2025-03-21       28.496691581 117.700000000
# 13 2025-03-24      169.318767026 121.410000000
# 14 2025-03-25      398.785502769 120.690000000
#
# Pearson Correlation between forecasted prices and actual prices: -0.4633258271509222  with a p-value of: 0.08196583806374809
#  Spearman Correlation between forecasted prices and actual prices: -0.38214285714285706  with a p-value of: 0.1598236299869673
#  Forecasted Root Mean Squared Error: 327.04160633281026
#  Forecasted Mean Absolute Error: 218.06924044668736
#  Mean Absolute Percentage Error: 191.65231291798366

# %% [markdown]
# # Sequential LSTM Model for Nvidia

# %%
separate_nvda_data.head()
# Out:
#         date   NVDA_close    NVDA_high     NVDA_low    NVDA_open  \
# 0 1999-01-22 19.690000000 23.440000000 18.630000000 21.000000000
# 1 1999-01-25 21.750000000 22.000000000 19.690000000 21.250000000
# 2 1999-01-26 20.060000000 22.440000000 19.750000000 22.000000000
# 3 1999-01-27 20.000000000 20.630000000 19.000000000 20.130000000
# 4 1999-01-28 19.940000000 20.130000000 19.810000000 20.000000000
#
#    NVDA_traded_volume  NVDA_adjClose  NVDA_adjLow  NVDA_adjOpen  \
# 0             5655600    0.037623625  0.035598178   0.040126771
# 1             1063500    0.041559870  0.037623625   0.040604471
# 2              715000    0.038330620  0.037738273   0.042037570
# 3              509100    0.038215972  0.036305174   0.038464376
# 4              474000    0.038101324  0.037852921   0.038215972
#
#    NVDA_adj_traded_volume  NVDA_divCash  NVDA_splitFactor           pe  \
# 0              2714686642   0.000000000       1.000000000 82.589342710
# 1               510479744   0.000000000       1.000000000 82.589342710
# 2               343199828   0.000000000       1.000000000 82.589342710
# 3               244367877   0.000000000       1.000000000 82.589342710
# 4               227519886   0.000000000       1.000000000 82.589342710
#
#    communicationServicesChangesPercentage  consumerCyclicalChangesPercentage  \
# 0                             0.853720000                       -0.307020000
# 1                             0.853720000                       -0.307020000
# 2                             0.853720000                       -0.307020000
# 3                             0.853720000                       -0.307020000
# 4                             0.853720000                       -0.307020000
#
#    consumerDefensiveChangesPercentage  energyChangesPercentage  \
# 0                        -0.737890000             -0.311530000
# 1                        -0.737890000             -0.311530000
# 2                        -0.737890000             -0.311530000
# 3                        -0.737890000             -0.311530000
# 4                        -0.737890000             -0.311530000
#
#    healthcareChangesPercentage  industrialsChangesPercentage  \
# 0                  0.781540000                   0.297280000
# 1                  0.781540000                   0.297280000
# 2                  0.781540000                   0.297280000
# 3                  0.781540000                   0.297280000
# 4                  0.781540000                   0.297280000
#
#    realEstateChangesPercentage  technologyChangesPercentage  \
# 0                  0.386630000                 -0.000910000
# 1                  0.386630000                 -0.000910000
# 2                  0.386630000                 -0.000910000
# 3                  0.386630000                 -0.000910000
# 4                  0.386630000                 -0.000910000
#
#    utilitiesChangesPercentage      month1      month3      month6       year1  \
# 0                -0.082430000 0.960000000 4.360000000 4.440000000 4.460000000
# 1                -0.082430000 0.960000000 4.440000000 4.450000000 4.480000000
# 2                -0.082430000 0.960000000 4.460000000 4.460000000 4.510000000
# 3                -0.082430000 0.960000000 4.470000000 4.470000000 4.510000000
# 4                -0.082430000 0.960000000 4.490000000 4.450000000 4.520000000
#
#         year2       year3       year5       year7      year10      year20  \
# 0 4.590000000 4.580000000 4.540000000 4.730000000 4.640000000 5.380000000
# 1 4.590000000 4.580000000 4.550000000 4.740000000 4.670000000 5.400000000
# 2 4.630000000 4.610000000 4.580000000 4.760000000 4.690000000 5.410000000
# 3 4.570000000 4.570000000 4.570000000 4.740000000 4.680000000 5.400000000
# 4 4.580000000 4.570000000 4.570000000 4.730000000 4.670000000 5.370000000
#
#        year30  inflationRate  Palladium_price  Palladium_volume  \
# 0 5.090000000    2.190000000    321.050000000      38.000000000
# 1 5.120000000    2.190000000    325.000000000     127.000000000
# 2 5.120000000    2.190000000    326.750000000      27.000000000
# 3 5.140000000    2.190000000    329.000000000      63.000000000
# 4 5.110000000    2.190000000    331.750000000      31.000000000
#
#    Palladium_open  Palladium_close  Copper_price  Copper_volume  Copper_open  \
# 0   320.000000000    321.050000000   0.657000000 6178.000000000  0.658500000
# 1   321.050000000    325.000000000   0.653500000 5340.000000000  0.652000000
# 2   325.500000000    326.750000000   0.649500000 7328.000000000  0.654000000
# 3   329.000000000    329.000000000   0.644000000 3401.000000000  0.643000000
# 4   328.550000000    331.750000000   0.643500000 8454.000000000  0.644000000
#
#    Copper_close  Lithium_price  Lithium_volume  Lithium_open  Lithium_close  \
# 0   0.657000000   11.187340531 29891.782535737  11.222459029   11.187340531
# 1   0.653500000   11.170448651 29891.782535737  11.191062484   11.170448651
# 2   0.649500000   11.151174874 29891.782535737  11.200713592   11.151174874
# 3   0.644000000   11.124727719 29891.782535737  11.147735301   11.124727719
# 4   0.643500000   11.122326544 29891.782535737  11.152541137   11.122326544
#
#    Silver_price  Silver_volume  Silver_open  Silver_close    Gold_price  \
# 0   5.115000000    0.000000000  5.115000000   5.115000000 286.450000000
# 1   5.185000000    0.000000000  5.100000000   5.185000000 287.850000000
# 2   5.115000000    0.000000000  5.175000000   5.115000000 286.150000000
# 3   5.095000000    0.000000000  5.115000000   5.095000000 283.000000000
# 4   5.235000000    0.000000000  5.100000000   5.235000000 284.250000000
#
#    Gold_volume     Gold_open    Gold_close         sma           adx  \
# 0  0.000000000 287.450000000 286.450000000 0.041601800 100.000000000
# 1  0.000000000 286.450000000 287.850000000 0.041601800 100.000000000
# 2  0.000000000 287.750000000 286.150000000 0.041797100 100.000000000
# 3  0.000000000 285.950000000 283.000000000 0.041666900 100.000000000
# 4  0.000000000 282.850000000 284.250000000 0.041536700   0.000000000
#
#          dema         ema         rsi  standardDeviation        tema  \
# 0 0.041601800 0.041601800 0.000000000        0.000000000 0.041601800
# 1 0.041601800 0.041601800 0.000000000        0.000000000 0.041601800
# 2 0.041797100 0.041797100 0.000000000        0.000000000 0.041797100
# 3 0.041666900 0.041666900 0.000000000        0.000000000 0.041666900
# 4 0.041536700 0.041536700 0.000000000        0.000000000 0.041536700
#
#        williams         wma NVDA_stock_news_sentiment  \
# 0 -74.180961264 0.041601800                   neutral
# 1 -74.180961264 0.041601800                   neutral
# 2 -88.371137703 0.041797100                   neutral
# 3 -38.461084035 0.041666900                   neutral
# 4 -59.990784826 0.041536700                   neutral
#
#   NVDA_press_release_sentiment  month  year  season
# 0                      neutral      1  1999  Winter
# 1                      neutral      1  1999  Winter
# 2                      neutral      1  1999  Winter
# 3                      neutral      1  1999  Winter
# 4                      neutral      1  1999  Winter

# %%
separate_nvda_data['date'] = pd.to_datetime(separate_nvda_data['date'])

separate_nvda_data['date_unix'] = separate_nvda_data['date'].astype('int64') // 10**9

s_nvda = separate_nvda_data

# Print the cleaned data
s_nvda.head()
# Out:
#         date   NVDA_close    NVDA_high     NVDA_low    NVDA_open  \
# 0 1999-01-22 19.690000000 23.440000000 18.630000000 21.000000000
# 1 1999-01-25 21.750000000 22.000000000 19.690000000 21.250000000
# 2 1999-01-26 20.060000000 22.440000000 19.750000000 22.000000000
# 3 1999-01-27 20.000000000 20.630000000 19.000000000 20.130000000
# 4 1999-01-28 19.940000000 20.130000000 19.810000000 20.000000000
#
#    NVDA_traded_volume  NVDA_adjClose  NVDA_adjLow  NVDA_adjOpen  \
# 0             5655600    0.037623625  0.035598178   0.040126771
# 1             1063500    0.041559870  0.037623625   0.040604471
# 2              715000    0.038330620  0.037738273   0.042037570
# 3              509100    0.038215972  0.036305174   0.038464376
# 4              474000    0.038101324  0.037852921   0.038215972
#
#    NVDA_adj_traded_volume  NVDA_divCash  NVDA_splitFactor           pe  \
# 0              2714686642   0.000000000       1.000000000 82.589342710
# 1               510479744   0.000000000       1.000000000 82.589342710
# 2               343199828   0.000000000       1.000000000 82.589342710
# 3               244367877   0.000000000       1.000000000 82.589342710
# 4               227519886   0.000000000       1.000000000 82.589342710
#
#    communicationServicesChangesPercentage  consumerCyclicalChangesPercentage  \
# 0                             0.853720000                       -0.307020000
# 1                             0.853720000                       -0.307020000
# 2                             0.853720000                       -0.307020000
# 3                             0.853720000                       -0.307020000
# 4                             0.853720000                       -0.307020000
#
#    consumerDefensiveChangesPercentage  energyChangesPercentage  \
# 0                        -0.737890000             -0.311530000
# 1                        -0.737890000             -0.311530000
# 2                        -0.737890000             -0.311530000
# 3                        -0.737890000             -0.311530000
# 4                        -0.737890000             -0.311530000
#
#    healthcareChangesPercentage  industrialsChangesPercentage  \
# 0                  0.781540000                   0.297280000
# 1                  0.781540000                   0.297280000
# 2                  0.781540000                   0.297280000
# 3                  0.781540000                   0.297280000
# 4                  0.781540000                   0.297280000
#
#    realEstateChangesPercentage  technologyChangesPercentage  \
# 0                  0.386630000                 -0.000910000
# 1                  0.386630000                 -0.000910000
# 2                  0.386630000                 -0.000910000
# 3                  0.386630000                 -0.000910000
# 4                  0.386630000                 -0.000910000
#
#    utilitiesChangesPercentage      month1      month3      month6       year1  \
# 0                -0.082430000 0.960000000 4.360000000 4.440000000 4.460000000
# 1                -0.082430000 0.960000000 4.440000000 4.450000000 4.480000000
# 2                -0.082430000 0.960000000 4.460000000 4.460000000 4.510000000
# 3                -0.082430000 0.960000000 4.470000000 4.470000000 4.510000000
# 4                -0.082430000 0.960000000 4.490000000 4.450000000 4.520000000
#
#         year2       year3       year5       year7      year10      year20  \
# 0 4.590000000 4.580000000 4.540000000 4.730000000 4.640000000 5.380000000
# 1 4.590000000 4.580000000 4.550000000 4.740000000 4.670000000 5.400000000
# 2 4.630000000 4.610000000 4.580000000 4.760000000 4.690000000 5.410000000
# 3 4.570000000 4.570000000 4.570000000 4.740000000 4.680000000 5.400000000
# 4 4.580000000 4.570000000 4.570000000 4.730000000 4.670000000 5.370000000
#
#        year30  inflationRate  Palladium_price  Palladium_volume  \
# 0 5.090000000    2.190000000    321.050000000      38.000000000
# 1 5.120000000    2.190000000    325.000000000     127.000000000
# 2 5.120000000    2.190000000    326.750000000      27.000000000
# 3 5.140000000    2.190000000    329.000000000      63.000000000
# 4 5.110000000    2.190000000    331.750000000      31.000000000
#
#    Palladium_open  Palladium_close  Copper_price  Copper_volume  Copper_open  \
# 0   320.000000000    321.050000000   0.657000000 6178.000000000  0.658500000
# 1   321.050000000    325.000000000   0.653500000 5340.000000000  0.652000000
# 2   325.500000000    326.750000000   0.649500000 7328.000000000  0.654000000
# 3   329.000000000    329.000000000   0.644000000 3401.000000000  0.643000000
# 4   328.550000000    331.750000000   0.643500000 8454.000000000  0.644000000
#
#    Copper_close  Lithium_price  Lithium_volume  Lithium_open  Lithium_close  \
# 0   0.657000000   11.187340531 29891.782535737  11.222459029   11.187340531
# 1   0.653500000   11.170448651 29891.782535737  11.191062484   11.170448651
# 2   0.649500000   11.151174874 29891.782535737  11.200713592   11.151174874
# 3   0.644000000   11.124727719 29891.782535737  11.147735301   11.124727719
# 4   0.643500000   11.122326544 29891.782535737  11.152541137   11.122326544
#
#    Silver_price  Silver_volume  Silver_open  Silver_close    Gold_price  \
# 0   5.115000000    0.000000000  5.115000000   5.115000000 286.450000000
# 1   5.185000000    0.000000000  5.100000000   5.185000000 287.850000000
# 2   5.115000000    0.000000000  5.175000000   5.115000000 286.150000000
# 3   5.095000000    0.000000000  5.115000000   5.095000000 283.000000000
# 4   5.235000000    0.000000000  5.100000000   5.235000000 284.250000000
#
#    Gold_volume     Gold_open    Gold_close         sma           adx  \
# 0  0.000000000 287.450000000 286.450000000 0.041601800 100.000000000
# 1  0.000000000 286.450000000 287.850000000 0.041601800 100.000000000
# 2  0.000000000 287.750000000 286.150000000 0.041797100 100.000000000
# 3  0.000000000 285.950000000 283.000000000 0.041666900 100.000000000
# 4  0.000000000 282.850000000 284.250000000 0.041536700   0.000000000
#
#          dema         ema         rsi  standardDeviation        tema  \
# 0 0.041601800 0.041601800 0.000000000        0.000000000 0.041601800
# 1 0.041601800 0.041601800 0.000000000        0.000000000 0.041601800
# 2 0.041797100 0.041797100 0.000000000        0.000000000 0.041797100
# 3 0.041666900 0.041666900 0.000000000        0.000000000 0.041666900
# 4 0.041536700 0.041536700 0.000000000        0.000000000 0.041536700
#
#        williams         wma NVDA_stock_news_sentiment  \
# 0 -74.180961264 0.041601800                   neutral
# 1 -74.180961264 0.041601800                   neutral
# 2 -88.371137703 0.041797100                   neutral
# 3 -38.461084035 0.041666900                   neutral
# 4 -59.990784826 0.041536700                   neutral
#
#   NVDA_press_release_sentiment  month  year  season  date_unix
# 0                      neutral      1  1999  Winter  916963200
# 1                      neutral      1  1999  Winter  917222400
# 2                      neutral      1  1999  Winter  917308800
# 3                      neutral      1  1999  Winter  917395200
# 4                      neutral      1  1999  Winter  917481600

# %%
# Scale the data
scaler = MinMaxScaler()
data_scaled = scaler.fit_transform(s_nvda[['NVDA_close']])

# Add the scaled values back to the data
s_nvda['NVDA_close_scaled'] = data_scaled

# %%
cat_cols = s_nvda.select_dtypes(include='object').columns

# Obtainig Dummies
s_nvda = pd.get_dummies(s_nvda, drop_first=True)

# Set a random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
random.seed(42)

# Split data into train and test
split_date = np.quantile(s_nvda['date_unix'], 0.85)
train_data = s_nvda[s_nvda['date_unix'] <= split_date]
test_data = s_nvda[s_nvda['date_unix'] > split_date]



# Create sequences for LSTM
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 27  # Sequence length for LSTM 27

# Use the scaled 'MSFT_close_scaled' column for sequence creation
train_scaled = train_data[['NVDA_close_scaled']].values
test_scaled = test_data[['NVDA_close_scaled']].values

X_train, y_train = create_sequences(train_scaled, seq_length)
X_test, y_test = create_sequences(test_scaled, seq_length)

# Reshape for LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
# Building LSTM model
lstm_model = Sequential()
lstm_model.add(LSTM(30, activation='relu', return_sequences=True, input_shape=(seq_length, 1), kernel_regularizer=l1_l2(200.5, 200.5)))
lstm_model.add(Dropout(0.4)) # Dropout of 40%
BatchNormalization(axis=1)
lstm_model.add(LSTM(60, activation='relu', return_sequences=False, kernel_regularizer=l1_l2(300.5, 200.5)))
lstm_model.add(Dropout(0.5)) # Dropout of 50%
BatchNormalization(axis=1)
lstm_model.add(Dense(20, activation='relu'))
lstm_model.add(Dense(1, activation='linear'))


lr_schedule = ExponentialDecay(initial_learning_rate=0.00001, decay_steps=10000, decay_rate=0.9) # 0.00001
optimizer = AdamW(learning_rate=lr_schedule)

# compiling the model
lstm_model.compile(optimizer=optimizer, loss='mean_squared_error')

# Training LSTM model 
lstm_model.fit(X_train, y_train, batch_size=40, epochs=40, verbose=1) # 35 25

# Predictions on the test set
y_train_pred = lstm_model.predict(X_train)
y_train_pred = scaler.inverse_transform(y_train_pred)  # Inverse transform predictions
y_train = scaler.inverse_transform(y_train.reshape(-1, 1))  # Inverse transform actual values


# Compute RMSE
train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
print(f'Training RMSE: {train_rmse}')


# Predictions on the test set
y_pred = lstm_model.predict(X_test)
y_pred = scaler.inverse_transform(y_pred)  # Inverse transform predictions
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))  # Inverse transform actual values


# Compute RMSE
test_rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f'Test RMSE: {test_rmse}')

# Plot actual vs predicted values
plt.figure(figsize=(12, 6))
sns.lineplot(x=train_data['date'].iloc[seq_length:], y=y_train.flatten(), label='Actual', color='blue')
sns.lineplot(x=train_data['date'].iloc[seq_length:], y=y_train_pred.flatten(), label='Predicted', color='red')
plt.xlabel("Date")
plt.ylabel("NVDA Close Price")
plt.title("Training Set: Actual vs Predicted Prices")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# Plot actual vs predicted values
plt.figure(figsize=(12, 6))
sns.lineplot(x=test_data['date'].iloc[seq_length:], y=y_test.flatten(), label='Actual', color='blue')
sns.lineplot(x=test_data['date'].iloc[seq_length:], y=y_pred.flatten(), label='Predicted', color='red')
plt.xlabel("Date")
plt.ylabel("NVDA Close Price")
plt.title("Test Set: Actual vs Predicted Prices")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# Forecast the next 15 days
future_predictions = []
input_seq = X_test[-1].reshape(1, seq_length, 1)

for _ in range(15):
    pred = lstm_model.predict(input_seq)[0, 0]
    future_predictions.append(pred)
    new_seq = np.append(input_seq[:, 1:, :], [[[pred]]], axis=1)
    input_seq = new_seq


# Convert forecasted values back to original scale
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1)).flatten()

# Create future dates
date_range = pd.date_range(start=pd.to_datetime(test_data['date'].max()) + pd.Timedelta(days=1), periods=15, freq='B')

# Plot forecasted prices
plt.figure(figsize=(12, 6))
sns.lineplot(x=date_range, y=future_predictions, label='Forecasted Prices', color='blue')
plt.xlabel("Date")
plt.ylabel("NVDA Close Price")
plt.title("LSTM Forecasted NVDA Close Prices for Next 15 Trading Days")
plt.legend()
plt.xticks(rotation=45)
plt.show()
# Out:
# c:\Users\ekf98\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:205: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - loss: 175398.1875
# Epoch 2/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 172053.5312
# Epoch 3/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 168747.9531
# Epoch 4/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 165482.1562
# Epoch 5/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 162256.9531
# Epoch 6/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - loss: 159071.4375
# Epoch 7/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: 155924.5781
# Epoch 8/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - loss: 152816.7500
# Epoch 9/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 149749.2812
# Epoch 10/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - loss: 146726.6250
# Epoch 11/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 143749.4688
# Epoch 12/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 48ms/step - loss: 140811.7344
# Epoch 13/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 47ms/step - loss: 137913.2969
# Epoch 14/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 47ms/step - loss: 135053.0625
# Epoch 15/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - loss: 132228.2188
# Epoch 16/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 129440.0625
# Epoch 17/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 126686.4609
# Epoch 18/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 123966.0156
# Epoch 19/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 121276.5938
# Epoch 20/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 118620.4062
# Epoch 21/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 115997.9219
# Epoch 22/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 113407.7188
# Epoch 23/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 37ms/step - loss: 110852.3750
# Epoch 24/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - loss: 108326.1797
# Epoch 25/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 40ms/step - loss: 105833.9219
# Epoch 26/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - loss: 103375.4219
# Epoch 27/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - loss: 100946.6484
# Epoch 28/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - loss: 98546.3984
# Epoch 29/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 96179.6875
# Epoch 30/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 93848.4062
# Epoch 31/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 91550.1406
# Epoch 32/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 89285.5078
# Epoch 33/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 87053.2578
# Epoch 34/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 84852.0781
# Epoch 35/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 41ms/step - loss: 82685.2656
# Epoch 36/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 80550.0625
# Epoch 37/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 42ms/step - loss: 78448.3828
# Epoch 38/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 76383.4531
# Epoch 39/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - loss: 74352.6953
# Epoch 40/40
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 6s 39ms/step - loss: 72352.7734
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 4s 20ms/step
# Training RMSE: 15.024615704056176
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Test RMSE: 147.32402068484438
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step

# %%
nvidia_lstm = pd.DataFrame({"date_range": date_range,
                         "future_predictions": future_predictions})

# nvidia_march_prices = pd.read_csv("march_prices/NVDA_march_prices.csv")


nvidia_lstm = pd.concat([nvidia_lstm, nvidia_march_prices['NVDA_close']], axis=1)

print(f" {nvidia_lstm} \n")

# Assuming you have two columns: 'future_predictions' and 'NVDA_close'
correlation, p_value = pearsonr(nvidia_lstm['future_predictions'], nvidia_lstm['NVDA_close'])

# Calculate Spearman's correlation
spearman_corr, p_value_spear = spearmanr(nvidia_lstm['future_predictions'], nvidia_lstm['NVDA_close'])


# Calculate Pearson correlation
correlation = nvidia_lstm[['future_predictions', 'NVDA_close']].corr().iloc[0, 1]


rmse = np.sqrt(np.mean((nvidia_lstm['NVDA_close'] - nvidia_lstm['future_predictions'])**2)) # for our given stock price ranges, rmse between 5-10 is good but the lower the better

mae = np.mean(np.abs((nvidia_lstm['NVDA_close'] - nvidia_lstm['future_predictions']))) # similarly for mae, the lower the better

mape = np.mean(np.abs((nvidia_lstm['NVDA_close'] - nvidia_lstm['future_predictions']) / nvidia_lstm['future_predictions'])) * 100 # aim for mape below 10% if possible


# Prioritising correlation overall is key. Hopefully the ARIMA model beats this correlation and improves the other metrics as well

print(f"Pearson Correlation between forecasted prices and actual prices: {correlation}  with a p-value of: {p_value} \n",
      f"Spearman Correlation between forecasted prices and actual prices: {spearman_corr}  with a p-value of: {p_value_spear} \n", 
       
      f"Forecasted Root Mean Squared Error: {rmse} \n",
      f"Forecasted Mean Absolute Error: {mae} \n",
      f"Mean Absolute Percentage Error: {mape} \n")

# reshaping data for plotting in seaborn
nvidia_melted = nvidia_lstm.melt(id_vars=['date_range'],
                               value_vars=['NVDA_close', 'future_predictions'],
                               var_name='Date',
                               value_name='Price')

# Plotting in Seaborn
plt.figure(figsize=(9, 8))
sns.lineplot(data=nvidia_melted, x='date_range', y='Price', hue='Date', markers='o')

# labels
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Actual Versus Forecasted Nvidia Stock Prices in March')
plt.xticks(rotation=45)
plt.grid(True)

plt.show()
# Out:
#     date_range  future_predictions    NVDA_close
# 0  2025-03-05       130.085784912 117.300000000
# 1  2025-03-06       129.004379272 110.570000000
# 2  2025-03-07       128.200454712 112.690000000
# 3  2025-03-10       128.901245117 106.980000000
# 4  2025-03-11       128.932052612 108.760000000
# 5  2025-03-12       129.323928833 115.740000000
# 6  2025-03-13       129.667831421 115.580000000
# 7  2025-03-14       130.332260132 121.670000000
# 8  2025-03-17       131.209533691 119.530000000
# 9  2025-03-18       131.957153320 115.430000000
# 10 2025-03-19       132.274765015 117.520000000
# 11 2025-03-20       132.336181641 118.530000000
# 12 2025-03-21       132.338668823 117.700000000
# 13 2025-03-24       132.114364624 121.410000000
# 14 2025-03-25       131.926696777 120.690000000
#
# Pearson Correlation between forecasted prices and actual prices: 0.7168749466278954  with a p-value of: 0.0026331947763158304
#  Spearman Correlation between forecasted prices and actual prices: 0.6892857142857142  with a p-value of: 0.0044737344509062004
#  Forecasted Root Mean Squared Error: 14.971893332389376
#  Forecasted Mean Absolute Error: 14.567020060221354
#  Mean Absolute Percentage Error: 11.171869359545523

# %% [markdown]
# # BI-LSTM Model for Apple

# %%
# Split data into train and test
split_date = np.quantile(s_nvda['date_unix'], 0.85)
train_data = s_nvda[s_nvda['date_unix'] <= split_date]
test_data = s_nvda[s_nvda['date_unix'] > split_date]



# Create sequences for LSTM
def create_sequences(data, seq_length):
    X, y = [], []
    for i in range(len(data) - seq_length):
        X.append(data[i:i+seq_length])
        y.append(data[i+seq_length])
    return np.array(X), np.array(y)

seq_length = 50  # Sequence length for Bi-LSTM 27

# Use the scaled 'MSFT_close_scaled' column for sequence creation
train_scaled = train_data[['NVDA_close_scaled']].values
test_scaled = test_data[['NVDA_close_scaled']].values

X_train, y_train = create_sequences(train_scaled, seq_length)
X_test, y_test = create_sequences(test_scaled, seq_length)

# Reshape for LSTM
X_train = X_train.reshape((X_train.shape[0], X_train.shape[1], 1))
X_test = X_test.reshape((X_test.shape[0], X_test.shape[1], 1))

# %%
# Define Bidirectional LSTM Model
bilstm_model = Sequential([
    Bidirectional(LSTM(30, activation='relu', kernel_regularizer=l1_l2(200.5, 200.5), return_sequences=True), input_shape=(seq_length, 1)),
    Dropout(0.2),
    BatchNormalization(),
    Bidirectional(LSTM(60, activation='relu', kernel_regularizer=l1_l2(300.5, 200.5), return_sequences=False), input_shape=(seq_length, 1)),
    Dropout(0.3),
    BatchNormalization(),
    # Bidirectional(LSTM(30, activation='relu', kernel_regularizer=l1_l2(300.5, 200.5), return_sequences=False), input_shape=(seq_length, 1)),
    # Dropout(0.3),
    # BatchNormalization(),
    Dense(30, activation='relu'),
    Dense(1, activation='linear')
])


lr_schedule = ExponentialDecay(initial_learning_rate=0.00001, decay_steps=10000, decay_rate=0.9)
bilstm_optimizer = AdamW(learning_rate=lr_schedule)

# Compile the bi-lstm model
bilstm_model.compile(optimizer=bilstm_optimizer, loss='mean_squared_error')

# Train the model
bilstm_model.fit(X_train, y_train, epochs=25, batch_size=32)

# Predictions on the training set
y_train_pred = bilstm_model.predict(X_train)
# y_train_pred = y_train_pred[:, -1, 0]  # Take the last time step's prediction
y_train_pred = y_train_pred[:, 0]  # Take the first (or appropriate) feature
y_train_pred = y_train_pred.reshape(-1, 1)  # Ensure 2D shape
y_train_pred = scaler.inverse_transform(y_train_pred)  # Inverse transform predictions
y_train = scaler.inverse_transform(y_train.reshape(-1, 1))  # Inverse transform actual values


# Compute RMSE
train_rmse = np.sqrt(mean_squared_error(y_train, y_train_pred))
print(f'Training RMSE: {train_rmse}')


# Predictions on the test set
y_pred = bilstm_model.predict(X_test)
# y_pred = y_pred[:, -1, 0]  # Take the last time step's prediction
y_pred = y_pred[:, 0]  # Take the first (or appropriate) feature
y_pred = y_pred.reshape(-1, 1)  # Ensure 2D shape
y_pred = scaler.inverse_transform(y_pred)  # Inverse transform predictions
y_test = scaler.inverse_transform(y_test.reshape(-1, 1))  # Inverse transform actual values

# Compute RMSE
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
print(f'Test RMSE: {rmse}')


# Plot actual vs predicted values
plt.figure(figsize=(12, 6))
sns.lineplot(x=train_data['date'].iloc[seq_length:], y=y_train.flatten(), label='Actual', color='blue')
sns.lineplot(x=train_data['date'].iloc[seq_length:], y=y_train_pred.flatten(), label='Predicted', color='red')
plt.xlabel("Date")
plt.ylabel("NVDA Close Price")
plt.title("Training Set: Actual vs Predicted Prices")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# Plot actual vs predicted values
plt.figure(figsize=(12, 6))
sns.lineplot(x=test_data['date'].iloc[seq_length:], y=y_test.flatten(), label='Actual', color='blue')
sns.lineplot(x=test_data['date'].iloc[seq_length:], y=y_pred.flatten(), label='Predicted', color='red')
plt.xlabel("Date")
plt.ylabel("NVDA Close Price")
plt.title("Test Set: Actual vs Predicted Prices")
plt.legend()
plt.xticks(rotation=45)
plt.show()

# Forecast the next 15 days
future_predictions = []
input_seq = X_test[-1].reshape(1, seq_length, 1)

for _ in range(15):
    pred = bilstm_model.predict(input_seq)[0, 0]
    pred = np.array(pred).reshape(1, 1, 1)  # Replace `num_features` with the correct value
    new_seq = np.append(input_seq[:, 1:, :], pred, axis=1)

    future_predictions.append(pred)
    # new_seq = np.append(input_seq[:, 1:, :], [[[pred]]], axis=1)
    input_seq = new_seq

# Convert forecasted values back to original scale
future_predictions = scaler.inverse_transform(np.array(future_predictions).reshape(-1, 1)).flatten()

# Create future dates
date_range = pd.date_range(start=pd.to_datetime(test_data['date'].max()) + pd.Timedelta(days=1), periods=15, freq='B')

# Plot forecasted prices
plt.figure(figsize=(12, 6))
sns.lineplot(x=date_range, y=future_predictions, label='Forecasted Prices', color='blue')
plt.xlabel("Date")
plt.ylabel("NVDA Close Price")
plt.title("Bi-LSTM Forecasted NVDA Close Prices for Next 15 Trading Days")
plt.legend()
plt.xticks(rotation=45)
plt.show()
# Out:
# c:\Users\ekf98\anaconda3\Lib\site-packages\keras\src\layers\core\wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 52s 89ms/step - loss: 648938.5625
# Epoch 2/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 91ms/step - loss: 632556.1250
# Epoch 3/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 93ms/step - loss: 616436.1250
# Epoch 4/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 17s 95ms/step - loss: 600584.6875
# Epoch 5/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 92ms/step - loss: 584990.5000
# Epoch 6/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 15s 88ms/step - loss: 569660.7500
# Epoch 7/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 89ms/step - loss: 554583.1875
# Epoch 8/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 90ms/step - loss: 539755.0625
# Epoch 9/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 16s 89ms/step - loss: 525156.1875
# Epoch 10/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 15s 88ms/step - loss: 510791.5938
# Epoch 11/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 17s 95ms/step - loss: 496667.1562
# Epoch 12/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 21s 96ms/step - loss: 482796.3125
# Epoch 13/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 17s 96ms/step - loss: 469160.2812
# Epoch 14/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 17s 97ms/step - loss: 455764.5312
# Epoch 15/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 17s 97ms/step - loss: 442607.8438
# Epoch 16/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 17s 97ms/step - loss: 429677.9062
# Epoch 17/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 17s 96ms/step - loss: 416967.9375
# Epoch 18/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 17s 97ms/step - loss: 404478.6562
# Epoch 19/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 17s 99ms/step - loss: 392209.6562
# Epoch 20/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 17s 97ms/step - loss: 380164.7500
# Epoch 21/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 15s 88ms/step - loss: 368343.9062
# Epoch 22/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 14s 83ms/step - loss: 356754.7188
# Epoch 23/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 13s 76ms/step - loss: 345381.5312
# Epoch 24/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 334232.2812
# Epoch 25/25
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 11s 61ms/step - loss: 323295.7812
# 174/174 ━━━━━━━━━━━━━━━━━━━━ 6s 28ms/step
# Training RMSE: 120.72654327387265
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# Test RMSE: 558.8769239654985
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step

# %%
nvidia_bilstm = pd.DataFrame({"date_range": date_range,
                         "future_predictions": future_predictions})

# nvidia_march_prices = pd.read_csv("march_prices/NVDA_march_prices.csv")


nvidia_bilstm = pd.concat([nvidia_bilstm, nvidia_march_prices['NVDA_close']], axis=1)


print(f" {nvidia_bilstm} \n")

# Assuming you have two columns: 'future_predictions' and 'NVDA_close'
correlation, p_value = pearsonr(nvidia_bilstm['future_predictions'], nvidia_bilstm['NVDA_close'])

# Calculate Spearman's correlation
spearman_corr, p_value_spear = spearmanr(nvidia_bilstm['future_predictions'], nvidia_bilstm['NVDA_close'])


# Calculate Pearson correlation
correlation = nvidia_bilstm[['future_predictions', 'NVDA_close']].corr().iloc[0, 1]


rmse = np.sqrt(np.mean((nvidia_bilstm['NVDA_close'] - nvidia_bilstm['future_predictions'])**2)) # for our given stock price ranges, rmse between 5-10 is good but the lower the better

mae = np.mean(np.abs((nvidia_bilstm['NVDA_close'] - nvidia_bilstm['future_predictions']))) # similarly for mae, the lower the better

mape = np.mean(np.abs((nvidia_bilstm['NVDA_close'] - nvidia_bilstm['future_predictions']) / nvidia_bilstm['future_predictions'])) * 100 # aim for mape below 10% if possible


# Prioritising correlation overall is key. Hopefully the ARIMA model beats this correlation and improves the other metrics as well

print(f"Pearson Correlation between forecasted prices and actual prices: {correlation}  with a p-value of: {p_value} \n",
      f"Spearman Correlation between forecasted prices and actual prices: {spearman_corr}  with a p-value of: {p_value_spear} \n", 
       
      f"Forecasted Root Mean Squared Error: {rmse} \n",
      f"Forecasted Mean Absolute Error: {mae} \n",
      f"Mean Absolute Percentage Error: {mape} \n")

# reshaping data for plotting in seaborn
nvidia_melted = nvidia_bilstm.melt(id_vars=['date_range'],
                               value_vars=['NVDA_close', 'future_predictions'],
                               var_name='Date',
                               value_name='Price')

# Plotting in Seaborn
plt.figure(figsize=(9, 8))
sns.lineplot(data=nvidia_melted, x='date_range', y='Price', hue='Date', markers='o')

# labels
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Actual Versus Forecasted Nvidia Stock Prices in March')
plt.xticks(rotation=45)
plt.grid(True)

plt.show()
# Out:
#     date_range  future_predictions    NVDA_close
# 0  2025-03-05       151.863891602 117.300000000
# 1  2025-03-06       166.480087280 110.570000000
# 2  2025-03-07       209.804534912 112.690000000
# 3  2025-03-10       294.316223145 106.980000000
# 4  2025-03-11       364.736206055 108.760000000
# 5  2025-03-12       377.510833740 115.740000000
# 6  2025-03-13       349.290100098 115.580000000
# 7  2025-03-14       350.502441406 121.670000000
# 8  2025-03-17       355.537109375 119.530000000
# 9  2025-03-18       354.084228516 115.430000000
# 10 2025-03-19       344.031921387 117.520000000
# 11 2025-03-20       324.567382812 118.530000000
# 12 2025-03-21       304.067382812 117.700000000
# 13 2025-03-24       280.760131836 121.410000000
# 14 2025-03-25       245.688095093 120.690000000
#
# Pearson Correlation between forecasted prices and actual prices: 0.13040740361662445  with a p-value of: 0.64319522604776
#  Spearman Correlation between forecasted prices and actual prices: 0.024999999999999998  with a p-value of: 0.9295289708192378
#  Forecasted Root Mean Squared Error: 195.28495730191963
#  Forecasted Mean Absolute Error: 182.20937133789064
#  Mean Absolute Percentage Error: 58.00193937049163
